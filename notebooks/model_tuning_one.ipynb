# %% [markdown]
# # Model Tuning
#
# This notebook will be dedicated to tuning the following models:
# 1. Logistic Regression
# 2. Gradient Boosting Trees
# 3. GRU
# 4. LSTM
#
# This notebook was put on Google Colab to leverage the GPU capabilities.

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score
import nltk
from nltk.corpus import stopwords
from sklearn.linear_model import LogisticRegression
from catboost import CatBoostClassifier
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense, GRU, LSTM, Embedding, Dropout, BatchNormalization
from keras.models import Sequential
import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import pickle
from google.colab import drive
drive.mount('/content/drive')

# %matplotlib inline
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Preprocessing class
class Preprocessing():
    # Constructor
    def __init__(self,strip_chars="#-'.;:)([]!?|/*@",replacements={"\n":" ", "\t": " ", "&gt":"", "&lt":"", "&amp":" and "}):
        """
        constructor

        Class constructor

        inputs:
        - strip_chars: a string of characters to strip from each word
        - replacements: a dictionary where key is the set of characters and the value is the value to replace
        the characters with.

        outputs:
        - None
        """
        self.strip_chars = strip_chars
        self.replacements = replacements

        # Creating a list for the stop words
        nltk.download('stopwords')
        self.stop_words = stopwords.words('english')

    # Creating a function to drop the columns
    def drop_columns(self,data,columns=['location','id','keyword']):
        """
        drop_columns

        A function to drop the listed columns in the data

        inputs:
        - data: data is a Pandas Dataframe containing the data
        - columns: a list of columns to drop

        outputs:
        - The new dataframe with the dropped columns
        """
        return data.drop(columns,axis=1)
        # try:
        #     return data.drop(columns,axis=1)
        # except Exception:
        #     return None

    # Creating a function to perform the preprocessing
    def preprocess_data(self,data):
        """
        preprocess_data

        A function to preprocess the data

        inputs:
        - data: a Pandas Dataframe containing the raw data

        outputs:
        - A numpy array containing the preprocessed sentences at each index
        """
        # Dropping the columns
        text_data = self.drop_columns(data)

        # Convert the text data to a numpy array
        text_data_arr = text_data.to_numpy()
        processed_sentences = []

        # Getting the preprocessed text
        for sentence in text_data_arr:
            # Making the replacements
            preprocessed_sentence = sentence[0]
            for replacements in self.replacements.keys():
                preprocessed_sentence = preprocessed_sentence.replace(replacements,self.replacements[replacements])

            # Splitting the sentence by space
            preprocessed_sentence_arr = preprocessed_sentence.split(' ')
            final_preprocessed_sentence = [] # an array for the preprocessed sentence

            for word in preprocessed_sentence_arr:
                processed_word = word.strip(self.strip_chars)
                processed_word = processed_word.lower()
                processed_word = processed_word.encode('ascii','ignore')
                processed_word = processed_word.decode()

                # Conditions to add it to the final preprocessed sentence
                if (processed_word != "") and (processed_word not in self.stop_words) and ("http" not in processed_word) and ("@" not in processed_word):
                    final_preprocessed_sentence.append(processed_word)

            processed_sentences.append(final_preprocessed_sentence)

        # returning the preprocessed sentences
        return processed_sentences

# %%
# Function for monitoring the model metrics
training_metrics = []
validation_metrics = []

# Creating a function that returns the metrics
def get_metrics(truth,predictions):
    f1 = f1_score(truth,predictions)
    precision = precision_score(truth,predictions)
    recall = recall_score(truth,predictions)
    accuracy = accuracy_score(truth,predictions)
    return f1, precision, recall, accuracy

# %% [markdown]
# ## Bag-of-Words Models
#
# For Logistic Regression and Gradient Boosting, I need to leverage the Bag-of-Words preprocessing approach.

# %% [markdown]
# ### Logistic Regression

# %%
# Importing the data
training = pd.read_csv('bag_of_words_training.csv')
testing = pd.read_csv('bag_of_words_testing.csv')

# Splitting testing data into validation
validation, testing = train_test_split(testing,test_size=0.2,random_state=42,shuffle=True,stratify=testing['Target'])
validation.reset_index(drop=True,inplace=True)

# Splitting data into X & y
train_x = training.drop(['ID','Target','Keyword'],axis=1)
train_y = training['Target'].values
valid_x = validation.drop(['ID','Target','Keyword'],axis=1)
valid_y = validation['Target'].values

# %%
# Performing a Randomized Search on the Logistic Regression Model
logReg = LogisticRegression(penalty='l2',random_state=42,max_iter=1500,tol=0.0001)
param_grid = {'C':np.random.uniform(low=0.6,high=2.0,size=100),'class_weight':['balanced',None]}
search = RandomizedSearchCV(logReg,param_grid,n_iter=200,scoring='f1',refit=True,cv=5,random_state=42)
search.fit(train_x,train_y)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=LogisticRegression(max_iter=1500, random_state=42),
#                    n_iter=200,
#                    param_distributions={'C': array([0.991282  , 1.42187341, 1.3893545 , 0.81242126, 1.66841046,
#        1.93765575, 0.98488368, 1.7435159 , 1.56115305, 0.74336121,
#        1.08875269, 1.79818893, 1.76643535, 1.56767174, 0.76137005,
#        1.98344615, 0.73762145, 1.73658121, 1.20335911, 1.23107097,
#        1.84952...
#        1.42951553, 1.30503297, 1.14858438, 1.81037005, 0.85351055,
#        1.48388021, 1.72598937, 1.06495677, 1.39314522, 1.94110905,
#        0.82526577, 1.33831607, 1.53396596, 0.97207791, 1.04242271,
#        0.75134087, 1.7316926 , 0.95864705, 1.96681452, 1.42291994,
#        1.81899251, 1.51756026, 1.31731854, 0.80149904, 1.51161129,
#        1.62556828, 1.33245042, 1.84963077, 1.57211515, 1.68109156]),
#                                         'class_weight': ['balanced', None]},
#                    random_state=42, scoring='f1')

# %%
# Looking at the best model
tuned_log_reg = search.best_estimator_
tuned_log_reg
# Out:
# LogisticRegression(C=0.6013348184634575, class_weight='balanced', max_iter=1500,
#                    random_state=42)

# %%
# Evaluating the Model on the Training Data and Validation Data
training_predictions = tuned_log_reg.predict(train_x)
validation_predictions = tuned_log_reg.predict(valid_x)
train_metrics = get_metrics(train_y,training_predictions)
valid_metrics = get_metrics(valid_y,validation_predictions)
train_metrics_df = {'Name':'Logistic Regression','F1':train_metrics[0],'Precision':train_metrics[1],'Recall':train_metrics[2],'Accuracy':train_metrics[3]}
valid_metrics_df = {'Name':'Logistic Regression','F1':valid_metrics[0],'Precision':valid_metrics[1],'Recall':valid_metrics[2],'Accuracy':valid_metrics[3]}

# %%
# Looking at the training results
train_metrics_df
# Out:
# {'Name': 'Logistic Regression',
#  'F1': 0.8074534161490682,
#  'Precision': 0.8205128205128205,
#  'Recall': 0.7948032097821933,
#  'Accuracy': 0.8371100164203612}

# %%
# Looking at the validation results
valid_metrics_df
# Out:
# {'Name': 'Logistic Regression',
#  'F1': 0.776923076923077,
#  'Precision': 0.781431334622824,
#  'Recall': 0.7724665391969407,
#  'Accuracy': 0.8095238095238095}

# %%
# Saving the model
with open('logistic-regression.sav','wb') as file:
    pickle.dump(tuned_log_reg,file)

# %% [markdown]
# ### Gradient Boosting

# %%
# Building the gradient boosting model
catboost_clf = CatBoostClassifier(loss_function='Logloss',random_state=42,early_stopping_rounds=10,eval_metric='F1',task_type='GPU')
param_grid = {'learning_rate':np.random.uniform(0.0001,0.9999,500),'depth':np.random.randint(1,3,size=7),
              'l2_leaf_reg':np.random.uniform(2,5,300),'min_data_in_leaf':np.random.randint(5,35,size=40),
              'iterations':np.random.randint(5,200,size=200),'auto_class_weights':[None,'Balanced','SqrtBalanced']}
search = catboost_clf.randomized_search(param_grid,train_x,train_y,cv=5,n_iter=300,refit=True,shuffle=True,stratified=True)
# Out:
# Streaming output truncated to the last 5000 lines.
# 132:	loss: 0.4075807	best: 0.7035464 (45)	total: 2m 42s	remaining: 3m 23s
# 0:	learn: 0.0496750	test: 0.0613718	best: 0.0613718 (0)	total: 60.9ms	remaining: 4.75s
# 1:	learn: 0.1055215	test: 0.1121359	best: 0.1121359 (1)	total: 120ms	remaining: 4.63s
# 2:	learn: 0.1557288	test: 0.1539503	best: 0.1539503 (2)	total: 181ms	remaining: 4.58s
# 3:	learn: 0.1969071	test: 0.2001320	best: 0.2001320 (3)	total: 242ms	remaining: 4.54s
# 4:	learn: 0.2108138	test: 0.2120595	best: 0.2120595 (4)	total: 308ms	remaining: 4.56s
# 5:	learn: 0.2274385	test: 0.2469119	best: 0.2469119 (5)	total: 368ms	remaining: 4.48s
# 6:	learn: 0.2386493	test: 0.2582294	best: 0.2582294 (6)	total: 428ms	remaining: 4.4s
# 7:	learn: 0.3034815	test: 0.3106962	best: 0.3106962 (7)	total: 487ms	remaining: 4.32s
# 8:	learn: 0.3371183	test: 0.3436112	best: 0.3436112 (8)	total: 557ms	remaining: 4.33s
# 9:	learn: 0.3435517	test: 0.3436112	best: 0.3436112 (8)	total: 619ms	remaining: 4.27s
# 10:	learn: 0.3587906	test: 0.3583268	best: 0.3583268 (10)	total: 681ms	remaining: 4.21s
# 11:	learn: 0.3731337	test: 0.3679928	best: 0.3679928 (11)	total: 743ms	remaining: 4.15s
# 12:	learn: 0.4017211	test: 0.3951677	best: 0.3951677 (12)	total: 802ms	remaining: 4.07s
# 13:	learn: 0.4162293	test: 0.3992553	best: 0.3992553 (13)	total: 861ms	remaining: 4s
# 14:	learn: 0.4289013	test: 0.4055738	best: 0.4055738 (14)	total: 923ms	remaining: 3.94s
# 15:	learn: 0.4390792	test: 0.4234592	best: 0.4234592 (15)	total: 984ms	remaining: 3.87s
# 16:	learn: 0.4536595	test: 0.4323450	best: 0.4323450 (16)	total: 1.04s	remaining: 3.8s
# 17:	learn: 0.4630519	test: 0.4420757	best: 0.4420757 (17)	total: 1.1s	remaining: 3.74s
# 18:	learn: 0.4798924	test: 0.4489772	best: 0.4489772 (18)	total: 1.17s	remaining: 3.69s
# 19:	learn: 0.4898415	test: 0.4573221	best: 0.4573221 (19)	total: 1.23s	remaining: 3.64s
# 20:	learn: 0.4996612	test: 0.4655777	best: 0.4655777 (20)	total: 1.29s	remaining: 3.57s
# 21:	learn: 0.4991476	test: 0.4655777	best: 0.4655777 (20)	total: 1.36s	remaining: 3.52s
# 22:	learn: 0.5069014	test: 0.4695392	best: 0.4695392 (22)	total: 1.43s	remaining: 3.47s
# 23:	learn: 0.5209056	test: 0.4825174	best: 0.4825174 (23)	total: 1.49s	remaining: 3.42s
# 24:	learn: 0.5311898	test: 0.4909906	best: 0.4909906 (24)	total: 1.55s	remaining: 3.35s
# 25:	learn: 0.5398071	test: 0.4963186	best: 0.4963186 (25)	total: 1.63s	remaining: 3.31s
# 26:	learn: 0.5473193	test: 0.4965917	best: 0.4965917 (26)	total: 1.69s	remaining: 3.25s
# 27:	learn: 0.5544173	test: 0.4985334	best: 0.4985334 (27)	total: 1.75s	remaining: 3.19s
# 28:	learn: 0.5589487	test: 0.4999104	best: 0.4999104 (28)	total: 1.81s	remaining: 3.12s
# 29:	learn: 0.5663722	test: 0.5127504	best: 0.5127504 (29)	total: 1.87s	remaining: 3.05s
# 30:	learn: 0.5755911	test: 0.5290504	best: 0.5290504 (30)	total: 1.93s	remaining: 2.99s
# 31:	learn: 0.5810121	test: 0.5303218	best: 0.5303218 (31)	total: 1.99s	remaining: 2.92s
# 32:	learn: 0.5883373	test: 0.5358418	best: 0.5358418 (32)	total: 2.05s	remaining: 2.86s
# 33:	learn: 0.5882140	test: 0.5358418	best: 0.5358418 (32)	total: 2.11s	remaining: 2.79s
# 34:	learn: 0.5939439	test: 0.5425508	best: 0.5425508 (34)	total: 2.17s	remaining: 2.73s
# 35:	learn: 0.6000520	test: 0.5443622	best: 0.5443622 (35)	total: 2.23s	remaining: 2.67s
# 36:	learn: 0.6112003	test: 0.5580685	best: 0.5580685 (36)	total: 2.29s	remaining: 2.6s
# 37:	learn: 0.6141768	test: 0.5668002	best: 0.5668002 (37)	total: 2.35s	remaining: 2.54s
# 38:	learn: 0.6184068	test: 0.5685339	best: 0.5685339 (38)	total: 2.41s	remaining: 2.47s
# 39:	learn: 0.6184767	test: 0.5697304	best: 0.5697304 (39)	total: 2.47s	remaining: 2.41s
# 40:	learn: 0.6243743	test: 0.5748261	best: 0.5748261 (40)	total: 2.5s	remaining: 2.32s
# 41:	learn: 0.6290387	test: 0.5850356	best: 0.5850356 (41)	total: 2.53s	remaining: 2.23s
# 42:	learn: 0.6342417	test: 0.5850356	best: 0.5850356 (41)	total: 2.56s	remaining: 2.14s
# 43:	learn: 0.6389932	test: 0.5967634	best: 0.5967634 (43)	total: 2.58s	remaining: 2.06s
# 44:	learn: 0.6438752	test: 0.5961507	best: 0.5967634 (43)	total: 2.65s	remaining: 2s
# 45:	learn: 0.6498928	test: 0.6005002	best: 0.6005002 (45)	total: 2.71s	remaining: 1.94s
# 46:	learn: 0.6530933	test: 0.6021461	best: 0.6021461 (46)	total: 2.77s	remaining: 1.89s
# 47:	learn: 0.6530933	test: 0.6021461	best: 0.6021461 (46)	total: 2.83s	remaining: 1.83s
# 48:	learn: 0.6578743	test: 0.6193746	best: 0.6193746 (48)	total: 2.89s	remaining: 1.77s
# 49:	learn: 0.6644173	test: 0.6329918	best: 0.6329918 (49)	total: 2.93s	remaining: 1.7s
# 50:	learn: 0.6691531	test: 0.6354708	best: 0.6354708 (50)	total: 2.94s	remaining: 1.61s
# 51:	learn: 0.6663959	test: 0.6251240	best: 0.6354708 (50)	total: 2.96s	remaining: 1.53s
# 52:	learn: 0.6687801	test: 0.6267079	best: 0.6354708 (50)	total: 2.97s	remaining: 1.46s
# 53:	learn: 0.6700889	test: 0.6298648	best: 0.6354708 (50)	total: 2.98s	remaining: 1.38s
# 54:	learn: 0.6745853	test: 0.6339426	best: 0.6354708 (50)	total: 3s	remaining: 1.31s
# 55:	learn: 0.6747548	test: 0.6339426	best: 0.6354708 (50)	total: 3.01s	remaining: 1.24s
# 56:	learn: 0.6747548	test: 0.6339426	best: 0.6354708 (50)	total: 3.03s	remaining: 1.17s
# 57:	learn: 0.6798420	test: 0.6398183	best: 0.6398183 (57)	total: 3.04s	remaining: 1.1s
# 58:	learn: 0.6842614	test: 0.6431692	best: 0.6431692 (58)	total: 3.05s	remaining: 1.03s
# 59:	learn: 0.6844914	test: 0.6450648	best: 0.6450648 (59)	total: 3.07s	remaining: 971ms
# 60:	learn: 0.6875614	test: 0.6498995	best: 0.6498995 (60)	total: 3.08s	remaining: 909ms
# 61:	learn: 0.6872893	test: 0.6498995	best: 0.6498995 (60)	total: 3.1s	remaining: 849ms
# 62:	learn: 0.6905451	test: 0.6538023	best: 0.6538023 (62)	total: 3.11s	remaining: 790ms
# 63:	learn: 0.6890549	test: 0.6559444	best: 0.6559444 (63)	total: 3.12s	remaining: 732ms
# 64:	learn: 0.6890549	test: 0.6559444	best: 0.6559444 (63)	total: 3.15s	remaining: 678ms
# 65:	learn: 0.6917214	test: 0.6538023	best: 0.6559444 (63)	total: 3.17s	remaining: 624ms
# 66:	learn: 0.6932325	test: 0.6570357	best: 0.6570357 (66)	total: 3.18s	remaining: 569ms
# 67:	learn: 0.6932325	test: 0.6570357	best: 0.6570357 (66)	total: 3.19s	remaining: 516ms
# 68:	learn: 0.6990983	test: 0.6690813	best: 0.6690813 (68)	total: 3.21s	remaining: 465ms
# 69:	learn: 0.6990983	test: 0.6690813	best: 0.6690813 (68)	total: 3.22s	remaining: 414ms
# 70:	learn: 0.7024592	test: 0.6763644	best: 0.6763644 (70)	total: 3.23s	remaining: 364ms
# 71:	learn: 0.7055553	test: 0.6773291	best: 0.6773291 (71)	total: 3.24s	remaining: 315ms
# 72:	learn: 0.7062928	test: 0.6773291	best: 0.6773291 (71)	total: 3.26s	remaining: 268ms
# 73:	learn: 0.7064443	test: 0.6738038	best: 0.6773291 (71)	total: 3.27s	remaining: 221ms
# 74:	learn: 0.7062741	test: 0.6752482	best: 0.6773291 (71)	total: 3.28s	remaining: 175ms
# 75:	learn: 0.7062741	test: 0.6758872	best: 0.6773291 (71)	total: 3.3s	remaining: 130ms
# 76:	learn: 0.7086299	test: 0.6738038	best: 0.6773291 (71)	total: 3.31s	remaining: 86ms
# 77:	learn: 0.7091741	test: 0.6752482	best: 0.6773291 (71)	total: 3.32s	remaining: 42.6ms
# 78:	learn: 0.7095148	test: 0.6758872	best: 0.6773291 (71)	total: 3.34s	remaining: 0us
# bestTest = 0.6773291075
# bestIteration = 71
# 133:	loss: 0.6773291	best: 0.7035464 (45)	total: 2m 47s	remaining: 3m 26s
# 0:	learn: 0.1071587	test: 0.1124780	best: 0.1124780 (0)	total: 14.3ms	remaining: 1.7s
# 1:	learn: 0.1596770	test: 0.1604818	best: 0.1604818 (1)	total: 27.3ms	remaining: 1.61s
# 2:	learn: 0.2167653	test: 0.2150167	best: 0.2150167 (2)	total: 40.3ms	remaining: 1.57s
# 3:	learn: 0.2701249	test: 0.2862479	best: 0.2862479 (3)	total: 53.3ms	remaining: 1.54s
# 4:	learn: 0.2946283	test: 0.3175677	best: 0.3175677 (4)	total: 66.2ms	remaining: 1.52s
# 5:	learn: 0.3685513	test: 0.3746912	best: 0.3746912 (5)	total: 79.2ms	remaining: 1.5s
# 6:	learn: 0.3966726	test: 0.4265745	best: 0.4265745 (6)	total: 92.2ms	remaining: 1.49s
# 7:	learn: 0.4379993	test: 0.4558819	best: 0.4558819 (7)	total: 106ms	remaining: 1.48s
# 8:	learn: 0.4498075	test: 0.4648142	best: 0.4648142 (8)	total: 119ms	remaining: 1.47s
# 9:	learn: 0.4664069	test: 0.4689758	best: 0.4689758 (9)	total: 132ms	remaining: 1.45s
# 10:	learn: 0.4934742	test: 0.4877515	best: 0.4877515 (10)	total: 146ms	remaining: 1.44s
# 11:	learn: 0.5013489	test: 0.4891990	best: 0.4891990 (11)	total: 159ms	remaining: 1.43s
# 12:	learn: 0.5172995	test: 0.5049936	best: 0.5049936 (12)	total: 172ms	remaining: 1.42s
# 13:	learn: 0.5372221	test: 0.5180824	best: 0.5180824 (13)	total: 192ms	remaining: 1.45s
# 14:	learn: 0.5487445	test: 0.5244834	best: 0.5244834 (14)	total: 217ms	remaining: 1.52s
# 15:	learn: 0.5628347	test: 0.5307916	best: 0.5307916 (15)	total: 238ms	remaining: 1.55s
# 16:	learn: 0.5802713	test: 0.5407983	best: 0.5407983 (16)	total: 252ms	remaining: 1.53s
# 17:	learn: 0.5933400	test: 0.5592516	best: 0.5592516 (17)	total: 265ms	remaining: 1.5s
# 18:	learn: 0.6074505	test: 0.5598234	best: 0.5598234 (18)	total: 279ms	remaining: 1.48s
# 19:	learn: 0.6178145	test: 0.5690697	best: 0.5690697 (19)	total: 291ms	remaining: 1.46s
# 20:	learn: 0.6262684	test: 0.5821361	best: 0.5821361 (20)	total: 313ms	remaining: 1.47s
# 21:	learn: 0.6314429	test: 0.5877986	best: 0.5877986 (21)	total: 325ms	remaining: 1.45s
# 22:	learn: 0.6440883	test: 0.6033778	best: 0.6033778 (22)	total: 340ms	remaining: 1.44s
# 23:	learn: 0.6590227	test: 0.6196231	best: 0.6196231 (23)	total: 353ms	remaining: 1.41s
# 24:	learn: 0.6667254	test: 0.6236943	best: 0.6236943 (24)	total: 366ms	remaining: 1.39s
# 25:	learn: 0.6706418	test: 0.6363521	best: 0.6363521 (25)	total: 379ms	remaining: 1.37s
# 26:	learn: 0.6812787	test: 0.6475097	best: 0.6475097 (26)	total: 392ms	remaining: 1.35s
# 27:	learn: 0.6887361	test: 0.6564477	best: 0.6564477 (27)	total: 405ms	remaining: 1.33s
# 28:	learn: 0.6887361	test: 0.6564477	best: 0.6564477 (27)	total: 430ms	remaining: 1.35s
# 29:	learn: 0.6960230	test: 0.6679264	best: 0.6679264 (29)	total: 450ms	remaining: 1.35s
# 30:	learn: 0.7002564	test: 0.6666714	best: 0.6679264 (29)	total: 462ms	remaining: 1.33s
# 31:	learn: 0.7064787	test: 0.6684825	best: 0.6684825 (31)	total: 475ms	remaining: 1.31s
# 32:	learn: 0.7082227	test: 0.6711629	best: 0.6711629 (32)	total: 488ms	remaining: 1.28s
# 33:	learn: 0.7122933	test: 0.6754370	best: 0.6754370 (33)	total: 503ms	remaining: 1.27s
# 34:	learn: 0.7122933	test: 0.6754370	best: 0.6754370 (33)	total: 516ms	remaining: 1.25s
# 35:	learn: 0.7138633	test: 0.6760662	best: 0.6760662 (35)	total: 529ms	remaining: 1.23s
# 36:	learn: 0.7161712	test: 0.6831319	best: 0.6831319 (36)	total: 542ms	remaining: 1.22s
# 37:	learn: 0.7204222	test: 0.6880957	best: 0.6880957 (37)	total: 554ms	remaining: 1.2s
# 38:	learn: 0.7204222	test: 0.6880957	best: 0.6880957 (37)	total: 567ms	remaining: 1.18s
# 39:	learn: 0.7204222	test: 0.6880957	best: 0.6880957 (37)	total: 580ms	remaining: 1.16s
# 40:	learn: 0.7223343	test: 0.6882198	best: 0.6882198 (40)	total: 594ms	remaining: 1.14s
# 41:	learn: 0.7258348	test: 0.6933346	best: 0.6933346 (41)	total: 606ms	remaining: 1.13s
# 42:	learn: 0.7256699	test: 0.6947017	best: 0.6947017 (42)	total: 619ms	remaining: 1.11s
# 43:	learn: 0.7287368	test: 0.6933346	best: 0.6947017 (42)	total: 645ms	remaining: 1.11s
# 44:	learn: 0.7299169	test: 0.6932265	best: 0.6947017 (42)	total: 658ms	remaining: 1.1s
# 45:	learn: 0.7300867	test: 0.6932265	best: 0.6947017 (42)	total: 674ms	remaining: 1.08s
# 46:	learn: 0.7300867	test: 0.6918525	best: 0.6947017 (42)	total: 690ms	remaining: 1.07s
# 47:	learn: 0.7300867	test: 0.6918525	best: 0.6947017 (42)	total: 703ms	remaining: 1.05s
# 48:	learn: 0.7329710	test: 0.6932265	best: 0.6947017 (42)	total: 716ms	remaining: 1.04s
# 49:	learn: 0.7356591	test: 0.6976178	best: 0.6976178 (49)	total: 728ms	remaining: 1.02s
# 50:	learn: 0.7363308	test: 0.6976178	best: 0.6976178 (49)	total: 741ms	remaining: 1s
# 51:	learn: 0.7373370	test: 0.6983398	best: 0.6983398 (51)	total: 754ms	remaining: 985ms
# 52:	learn: 0.7363543	test: 0.6928141	best: 0.6983398 (51)	total: 767ms	remaining: 969ms
# 53:	learn: 0.7385446	test: 0.6929226	best: 0.6983398 (51)	total: 780ms	remaining: 953ms
# 54:	learn: 0.7403665	test: 0.6922974	best: 0.6983398 (51)	total: 793ms	remaining: 937ms
# 55:	learn: 0.7405370	test: 0.6922974	best: 0.6983398 (51)	total: 806ms	remaining: 921ms
# 56:	learn: 0.7435203	test: 0.6924071	best: 0.6983398 (51)	total: 819ms	remaining: 905ms
# 57:	learn: 0.7435203	test: 0.6924071	best: 0.6983398 (51)	total: 832ms	remaining: 889ms
# 58:	learn: 0.7450390	test: 0.6930306	best: 0.6983398 (51)	total: 860ms	remaining: 889ms
# 59:	learn: 0.7471525	test: 0.6944886	best: 0.6983398 (51)	total: 874ms	remaining: 874ms
# 60:	learn: 0.7476534	test: 0.6944886	best: 0.6983398 (51)	total: 886ms	remaining: 857ms
# 61:	learn: 0.7481667	test: 0.6931380	best: 0.6983398 (51)	total: 899ms	remaining: 841ms
# bestTest = 0.6983397646
# bestIteration = 51
# 134:	loss: 0.6983398	best: 0.7035464 (45)	total: 2m 48s	remaining: 3m 25s
# 0:	learn: 0.0496750	test: 0.0613718	best: 0.0613718 (0)	total: 13.8ms	remaining: 900ms
# 1:	learn: 0.1037966	test: 0.1056583	best: 0.1056583 (1)	total: 27.4ms	remaining: 876ms
# 2:	learn: 0.1360420	test: 0.1287252	best: 0.1287252 (2)	total: 39.7ms	remaining: 834ms
# 3:	learn: 0.1781600	test: 0.1763106	best: 0.1763106 (3)	total: 51.9ms	remaining: 804ms
# 4:	learn: 0.1923680	test: 0.1885941	best: 0.1885941 (4)	total: 63.8ms	remaining: 779ms
# 5:	learn: 0.2642487	test: 0.2522283	best: 0.2522283 (5)	total: 87.1ms	remaining: 871ms
# 6:	learn: 0.2821183	test: 0.2684416	best: 0.2684416 (6)	total: 99.5ms	remaining: 839ms
# 7:	learn: 0.3006630	test: 0.2980049	best: 0.2980049 (7)	total: 112ms	remaining: 813ms
# 8:	learn: 0.3344180	test: 0.3315784	best: 0.3315784 (8)	total: 124ms	remaining: 788ms
# 9:	learn: 0.3546523	test: 0.3554348	best: 0.3554348 (9)	total: 137ms	remaining: 765ms
# 10:	learn: 0.3740014	test: 0.3713638	best: 0.3713638 (10)	total: 149ms	remaining: 745ms
# 11:	learn: 0.3886114	test: 0.3855266	best: 0.3855266 (11)	total: 161ms	remaining: 724ms
# 12:	learn: 0.4164119	test: 0.4118234	best: 0.4118234 (12)	total: 173ms	remaining: 707ms
# 13:	learn: 0.4299594	test: 0.4157830	best: 0.4157830 (13)	total: 192ms	remaining: 713ms
# 14:	learn: 0.4466306	test: 0.4543104	best: 0.4543104 (14)	total: 219ms	remaining: 744ms
# 15:	learn: 0.4570553	test: 0.4710482	best: 0.4710482 (15)	total: 233ms	remaining: 727ms
# 16:	learn: 0.4711268	test: 0.4790899	best: 0.4790899 (16)	total: 245ms	remaining: 705ms
# 17:	learn: 0.4802236	test: 0.4880726	best: 0.4880726 (17)	total: 257ms	remaining: 685ms
# 18:	learn: 0.4959796	test: 0.4940772	best: 0.4940772 (18)	total: 269ms	remaining: 665ms
# 19:	learn: 0.5041325	test: 0.4999592	best: 0.4999592 (19)	total: 281ms	remaining: 646ms
# 20:	learn: 0.5147001	test: 0.5077308	best: 0.5077308 (20)	total: 306ms	remaining: 656ms
# 21:	learn: 0.5137001	test: 0.5057955	best: 0.5077308 (20)	total: 318ms	remaining: 637ms
# 22:	learn: 0.5205352	test: 0.5093019	best: 0.5093019 (22)	total: 331ms	remaining: 618ms
# 23:	learn: 0.5318162	test: 0.5163580	best: 0.5163580 (23)	total: 343ms	remaining: 600ms
# 24:	learn: 0.5419151	test: 0.5244834	best: 0.5244834 (24)	total: 355ms	remaining: 583ms
# 25:	learn: 0.5503391	test: 0.5295141	best: 0.5295141 (25)	total: 368ms	remaining: 566ms
# 26:	learn: 0.5576931	test: 0.5296295	best: 0.5296295 (26)	total: 380ms	remaining: 549ms
# 27:	learn: 0.5646578	test: 0.5314814	best: 0.5314814 (27)	total: 392ms	remaining: 532ms
# 28:	learn: 0.5690888	test: 0.5327468	best: 0.5327468 (28)	total: 404ms	remaining: 516ms
# 29:	learn: 0.5763629	test: 0.5449501	best: 0.5449501 (29)	total: 416ms	remaining: 499ms
# 30:	learn: 0.5849140	test: 0.5604642	best: 0.5604642 (30)	total: 428ms	remaining: 484ms
# 31:	learn: 0.5902396	test: 0.5616328	best: 0.5616328 (31)	total: 441ms	remaining: 468ms
# 32:	learn: 0.5950864	test: 0.5721385	best: 0.5721385 (32)	total: 453ms	remaining: 453ms
# 33:	learn: 0.5978780	test: 0.5721385	best: 0.5721385 (32)	total: 465ms	remaining: 437ms
# 34:	learn: 0.6033258	test: 0.5784492	best: 0.5784492 (34)	total: 477ms	remaining: 422ms
# 35:	learn: 0.6138186	test: 0.5934325	best: 0.5934325 (35)	total: 491ms	remaining: 409ms
# 36:	learn: 0.6244609	test: 0.6056144	best: 0.6056144 (36)	total: 516ms	remaining: 405ms
# 37:	learn: 0.6301263	test: 0.6072364	best: 0.6072364 (37)	total: 528ms	remaining: 389ms
# 38:	learn: 0.6341974	test: 0.6088547	best: 0.6088547 (38)	total: 541ms	remaining: 374ms
# 39:	learn: 0.6394538	test: 0.6104693	best: 0.6104693 (39)	total: 553ms	remaining: 360ms
# 40:	learn: 0.6454416	test: 0.6150399	best: 0.6150399 (40)	total: 566ms	remaining: 345ms
# 41:	learn: 0.6478283	test: 0.6166332	best: 0.6166332 (41)	total: 578ms	remaining: 330ms
# 42:	learn: 0.6524109	test: 0.6166332	best: 0.6166332 (41)	total: 590ms	remaining: 315ms
# 43:	learn: 0.6454122	test: 0.6041956	best: 0.6166332 (41)	total: 602ms	remaining: 301ms
# 44:	learn: 0.6502209	test: 0.6035821	best: 0.6166332 (41)	total: 614ms	remaining: 286ms
# 45:	learn: 0.6553461	test: 0.6078502	best: 0.6166332 (41)	total: 626ms	remaining: 272ms
# 46:	learn: 0.6585029	test: 0.6094695	best: 0.6166332 (41)	total: 638ms	remaining: 258ms
# 47:	learn: 0.6585029	test: 0.6094695	best: 0.6166332 (41)	total: 651ms	remaining: 244ms
# 48:	learn: 0.6615310	test: 0.6150399	best: 0.6166332 (41)	total: 666ms	remaining: 231ms
# 49:	learn: 0.6657992	test: 0.6169919	best: 0.6169919 (49)	total: 679ms	remaining: 217ms
# 50:	learn: 0.6707370	test: 0.6195414	best: 0.6195414 (50)	total: 691ms	remaining: 203ms
# 51:	learn: 0.6766732	test: 0.6211176	best: 0.6211176 (51)	total: 703ms	remaining: 189ms
# 52:	learn: 0.6789885	test: 0.6226902	best: 0.6226902 (52)	total: 738ms	remaining: 181ms
# 53:	learn: 0.6817456	test: 0.6258245	best: 0.6258245 (53)	total: 751ms	remaining: 167ms
# 54:	learn: 0.6861046	test: 0.6298794	best: 0.6298794 (54)	total: 764ms	remaining: 153ms
# 55:	learn: 0.6858305	test: 0.6298794	best: 0.6298794 (54)	total: 776ms	remaining: 139ms
# 56:	learn: 0.6859998	test: 0.6298794	best: 0.6298794 (54)	total: 789ms	remaining: 125ms
# 57:	learn: 0.6907639	test: 0.6357316	best: 0.6357316 (57)	total: 801ms	remaining: 111ms
# 58:	learn: 0.6910102	test: 0.6412849	best: 0.6412849 (58)	total: 815ms	remaining: 96.7ms
# 59:	learn: 0.6937725	test: 0.6412849	best: 0.6412849 (58)	total: 827ms	remaining: 82.7ms
# 60:	learn: 0.6953319	test: 0.6400347	best: 0.6412849 (58)	total: 840ms	remaining: 68.8ms
# 61:	learn: 0.6955021	test: 0.6406592	best: 0.6412849 (58)	total: 852ms	remaining: 55ms
# 62:	learn: 0.6986840	test: 0.6446005	best: 0.6446005 (62)	total: 865ms	remaining: 41.2ms
# 63:	learn: 0.6998033	test: 0.6439749	best: 0.6446005 (62)	total: 877ms	remaining: 27.4ms
# 64:	learn: 0.6998033	test: 0.6439749	best: 0.6446005 (62)	total: 890ms	remaining: 13.7ms
# 65:	learn: 0.7022674	test: 0.6433506	best: 0.6446005 (62)	total: 902ms	remaining: 0us
# bestTest = 0.644600516
# bestIteration = 62
# 135:	loss: 0.6446005	best: 0.7035464 (45)	total: 2m 49s	remaining: 3m 23s
# 0:	learn: 0.1165202	test: 0.1054971	best: 0.1054971 (0)	total: 14ms	remaining: 631ms
# 1:	learn: 0.1596770	test: 0.1604818	best: 0.1604818 (1)	total: 26.9ms	remaining: 592ms
# 2:	learn: 0.2167653	test: 0.2150167	best: 0.2150167 (2)	total: 40.1ms	remaining: 575ms
# 3:	learn: 0.2701249	test: 0.2862479	best: 0.2862479 (3)	total: 53.1ms	remaining: 558ms
# 4:	learn: 0.2946283	test: 0.3175677	best: 0.3175677 (4)	total: 67.7ms	remaining: 555ms
# 5:	learn: 0.3685513	test: 0.3746912	best: 0.3746912 (5)	total: 81.1ms	remaining: 541ms
# 6:	learn: 0.3966726	test: 0.4265745	best: 0.4265745 (6)	total: 94.5ms	remaining: 526ms
# 7:	learn: 0.4379993	test: 0.4558819	best: 0.4558819 (7)	total: 110ms	remaining: 521ms
# 8:	learn: 0.4566353	test: 0.4663484	best: 0.4663484 (8)	total: 131ms	remaining: 538ms
# 9:	learn: 0.4730093	test: 0.4704954	best: 0.4704954 (9)	total: 144ms	remaining: 518ms
# 10:	learn: 0.4995692	test: 0.4891990	best: 0.4891990 (10)	total: 157ms	remaining: 499ms
# 11:	learn: 0.5073491	test: 0.4906393	best: 0.4906393 (11)	total: 169ms	remaining: 480ms
# 12:	learn: 0.5189018	test: 0.4940645	best: 0.4940645 (12)	total: 182ms	remaining: 462ms
# 13:	learn: 0.5407521	test: 0.5069369	best: 0.5069369 (13)	total: 208ms	remaining: 475ms
# 14:	learn: 0.5522155	test: 0.5135069	best: 0.5135069 (14)	total: 234ms	remaining: 484ms
# 15:	learn: 0.5581823	test: 0.5260953	best: 0.5260953 (15)	total: 247ms	remaining: 463ms
# 16:	learn: 0.5733308	test: 0.5386216	best: 0.5386216 (16)	total: 261ms	remaining: 445ms
# 17:	learn: 0.5866448	test: 0.5575483	best: 0.5575483 (17)	total: 274ms	remaining: 426ms
# 18:	learn: 0.6038718	test: 0.5622638	best: 0.5622638 (18)	total: 287ms	remaining: 408ms
# 19:	learn: 0.6142440	test: 0.5722144	best: 0.5722144 (19)	total: 300ms	remaining: 390ms
# 20:	learn: 0.6235427	test: 0.5739580	best: 0.5739580 (20)	total: 313ms	remaining: 373ms
# 21:	learn: 0.6375369	test: 0.5903900	best: 0.5903900 (21)	total: 326ms	remaining: 356ms
# 22:	learn: 0.6481195	test: 0.5979927	best: 0.5979927 (22)	total: 339ms	remaining: 339ms
# 23:	learn: 0.6614744	test: 0.6175094	best: 0.6175094 (23)	total: 352ms	remaining: 323ms
# 24:	learn: 0.6687685	test: 0.6210464	best: 0.6210464 (24)	total: 365ms	remaining: 307ms
# 25:	learn: 0.6726812	test: 0.6333136	best: 0.6333136 (25)	total: 378ms	remaining: 291ms
# 26:	learn: 0.6815770	test: 0.6446985	best: 0.6446985 (26)	total: 392ms	remaining: 276ms
# 27:	learn: 0.6890409	test: 0.6538023	best: 0.6538023 (27)	total: 405ms	remaining: 260ms
# 28:	learn: 0.6890409	test: 0.6538023	best: 0.6538023 (27)	total: 418ms	remaining: 245ms
# 29:	learn: 0.6898120	test: 0.6546722	best: 0.6546722 (29)	total: 430ms	remaining: 230ms
# 30:	learn: 0.6959346	test: 0.6589678	best: 0.6589678 (30)	total: 453ms	remaining: 219ms
# 31:	learn: 0.6991962	test: 0.6564477	best: 0.6589678 (30)	total: 466ms	remaining: 204ms
# 32:	learn: 0.7008552	test: 0.6638062	best: 0.6638062 (32)	total: 479ms	remaining: 189ms
# 33:	learn: 0.7008552	test: 0.6638062	best: 0.6638062 (32)	total: 492ms	remaining: 174ms
# 34:	learn: 0.7077327	test: 0.6690020	best: 0.6690020 (34)	total: 505ms	remaining: 159ms
# 35:	learn: 0.7102307	test: 0.6698178	best: 0.6698178 (35)	total: 518ms	remaining: 144ms
# 36:	learn: 0.7151122	test: 0.6760662	best: 0.6760662 (36)	total: 530ms	remaining: 129ms
# 37:	learn: 0.7189499	test: 0.6796836	best: 0.6796836 (37)	total: 543ms	remaining: 114ms
# 38:	learn: 0.7231026	test: 0.6824996	best: 0.6824996 (38)	total: 555ms	remaining: 99.7ms
# 39:	learn: 0.7215480	test: 0.6773281	best: 0.6824996 (38)	total: 568ms	remaining: 85.2ms
# 40:	learn: 0.7249914	test: 0.6789016	best: 0.6824996 (38)	total: 581ms	remaining: 70.9ms
# 41:	learn: 0.7285734	test: 0.6874620	best: 0.6874620 (41)	total: 594ms	remaining: 56.6ms
# 42:	learn: 0.7285751	test: 0.6880957	best: 0.6880957 (42)	total: 607ms	remaining: 42.4ms
# 43:	learn: 0.7282350	test: 0.6888530	best: 0.6888530 (43)	total: 621ms	remaining: 28.2ms
# 44:	learn: 0.7312735	test: 0.6909918	best: 0.6909918 (44)	total: 649ms	remaining: 14.4ms
# 45:	learn: 0.7331189	test: 0.6944929	best: 0.6944929 (45)	total: 662ms	remaining: 0us
# bestTest = 0.6944928867
# bestIteration = 45
# 136:	loss: 0.6944929	best: 0.7035464 (45)	total: 2m 49s	remaining: 3m 22s
# 0:	learn: 0.0496750	test: 0.0613718	best: 0.0613718 (0)	total: 13.4ms	remaining: 1.31s
# 1:	learn: 0.1037966	test: 0.1056583	best: 0.1056583 (1)	total: 26ms	remaining: 1.26s
# 2:	learn: 0.1360420	test: 0.1287252	best: 0.1287252 (2)	total: 38.6ms	remaining: 1.23s
# 3:	learn: 0.1781600	test: 0.1763106	best: 0.1763106 (3)	total: 50.8ms	remaining: 1.21s
# 4:	learn: 0.1923680	test: 0.1885941	best: 0.1885941 (4)	total: 63.6ms	remaining: 1.2s
# 5:	learn: 0.2642487	test: 0.2522283	best: 0.2522283 (5)	total: 76ms	remaining: 1.18s
# 6:	learn: 0.2821183	test: 0.2684416	best: 0.2684416 (6)	total: 88.6ms	remaining: 1.16s
# 7:	learn: 0.3006630	test: 0.2980049	best: 0.2980049 (7)	total: 113ms	remaining: 1.28s
# 8:	learn: 0.3344180	test: 0.3315784	best: 0.3315784 (8)	total: 125ms	remaining: 1.25s
# 9:	learn: 0.3546523	test: 0.3554348	best: 0.3554348 (9)	total: 138ms	remaining: 1.23s
# 10:	learn: 0.3740014	test: 0.3713638	best: 0.3713638 (10)	total: 150ms	remaining: 1.2s
# 11:	learn: 0.3886114	test: 0.3855266	best: 0.3855266 (11)	total: 163ms	remaining: 1.18s
# 12:	learn: 0.4164119	test: 0.4118234	best: 0.4118234 (12)	total: 177ms	remaining: 1.17s
# 13:	learn: 0.4299594	test: 0.4157830	best: 0.4157830 (13)	total: 190ms	remaining: 1.15s
# 14:	learn: 0.4466306	test: 0.4543104	best: 0.4543104 (14)	total: 202ms	remaining: 1.13s
# 15:	learn: 0.4570553	test: 0.4710482	best: 0.4710482 (15)	total: 221ms	remaining: 1.14s
# 16:	learn: 0.4711268	test: 0.4790899	best: 0.4790899 (16)	total: 233ms	remaining: 1.13s
# 17:	learn: 0.4802236	test: 0.4880726	best: 0.4880726 (17)	total: 246ms	remaining: 1.1s
# 18:	learn: 0.4959796	test: 0.4940772	best: 0.4940772 (18)	total: 258ms	remaining: 1.09s
# 19:	learn: 0.5041325	test: 0.4999592	best: 0.4999592 (19)	total: 270ms	remaining: 1.07s
# 20:	learn: 0.5147001	test: 0.5077308	best: 0.5077308 (20)	total: 282ms	remaining: 1.05s
# 21:	learn: 0.5137001	test: 0.5057955	best: 0.5077308 (20)	total: 295ms	remaining: 1.03s
# 22:	learn: 0.5205352	test: 0.5093019	best: 0.5093019 (22)	total: 307ms	remaining: 1.01s
# 23:	learn: 0.5318162	test: 0.5163580	best: 0.5163580 (23)	total: 332ms	remaining: 1.04s
# 24:	learn: 0.5412978	test: 0.5233268	best: 0.5233268 (24)	total: 346ms	remaining: 1.02s
# 25:	learn: 0.5497175	test: 0.5283521	best: 0.5283521 (25)	total: 358ms	remaining: 1s
# 26:	learn: 0.5570673	test: 0.5284725	best: 0.5284725 (26)	total: 370ms	remaining: 988ms
# 27:	learn: 0.5646578	test: 0.5314814	best: 0.5314814 (27)	total: 383ms	remaining: 970ms
# 28:	learn: 0.5719934	test: 0.5437255	best: 0.5437255 (28)	total: 395ms	remaining: 953ms
# 29:	learn: 0.5779075	test: 0.5431375	best: 0.5437255 (28)	total: 407ms	remaining: 936ms
# 30:	learn: 0.5868901	test: 0.5586927	best: 0.5586927 (30)	total: 419ms	remaining: 920ms
# 31:	learn: 0.5951825	test: 0.5726658	best: 0.5726658 (31)	total: 441ms	remaining: 923ms
# 32:	learn: 0.6023552	test: 0.5789525	best: 0.5789525 (32)	total: 458ms	remaining: 916ms
# 33:	learn: 0.6049408	test: 0.5789525	best: 0.5789525 (32)	total: 471ms	remaining: 900ms
# 34:	learn: 0.6118263	test: 0.5834673	best: 0.5834673 (34)	total: 486ms	remaining: 888ms
# 35:	learn: 0.6222018	test: 0.5982383	best: 0.5982383 (35)	total: 498ms	remaining: 872ms
# 36:	learn: 0.6276659	test: 0.6046005	best: 0.6046005 (36)	total: 511ms	remaining: 856ms
# 37:	learn: 0.6333057	test: 0.6062272	best: 0.6062272 (37)	total: 524ms	remaining: 842ms
# 38:	learn: 0.6373610	test: 0.6078502	best: 0.6078502 (38)	total: 549ms	remaining: 845ms
# 39:	learn: 0.6425970	test: 0.6094695	best: 0.6094695 (39)	total: 562ms	remaining: 828ms
# 40:	learn: 0.6485558	test: 0.6140575	best: 0.6140575 (40)	total: 574ms	remaining: 811ms
# 41:	learn: 0.6525766	test: 0.6235898	best: 0.6235898 (41)	total: 586ms	remaining: 795ms
# 42:	learn: 0.6571254	test: 0.6235898	best: 0.6235898 (41)	total: 598ms	remaining: 779ms
# 43:	learn: 0.6599168	test: 0.6229699	best: 0.6235898 (41)	total: 616ms	remaining: 770ms
# 44:	learn: 0.6649623	test: 0.6223512	best: 0.6235898 (41)	total: 628ms	remaining: 754ms
# 45:	learn: 0.6683645	test: 0.6264433	best: 0.6264433 (45)	total: 641ms	remaining: 738ms
# 46:	learn: 0.6714291	test: 0.6280060	best: 0.6280060 (46)	total: 653ms	remaining: 723ms
# 47:	learn: 0.6714291	test: 0.6280060	best: 0.6280060 (46)	total: 666ms	remaining: 707ms
# 48:	learn: 0.6750793	test: 0.6332789	best: 0.6332789 (48)	total: 680ms	remaining: 694ms
# 49:	learn: 0.6780578	test: 0.6351124	best: 0.6351124 (49)	total: 692ms	remaining: 678ms
# 50:	learn: 0.6828342	test: 0.6375490	best: 0.6375490 (50)	total: 704ms	remaining: 663ms
# 51:	learn: 0.6886003	test: 0.6390712	best: 0.6390712 (51)	total: 716ms	remaining: 647ms
# 52:	learn: 0.6908426	test: 0.6405900	best: 0.6405900 (52)	total: 728ms	remaining: 632ms
# 53:	learn: 0.6908426	test: 0.6405900	best: 0.6405900 (52)	total: 741ms	remaining: 617ms
# 54:	learn: 0.6943680	test: 0.6445039	best: 0.6445039 (54)	total: 766ms	remaining: 613ms
# 55:	learn: 0.6945367	test: 0.6445039	best: 0.6445039 (54)	total: 778ms	remaining: 598ms
# 56:	learn: 0.6947054	test: 0.6445039	best: 0.6445039 (54)	total: 790ms	remaining: 582ms
# 57:	learn: 0.6968939	test: 0.6475097	best: 0.6475097 (57)	total: 803ms	remaining: 567ms
# 58:	learn: 0.7007175	test: 0.6579259	best: 0.6579259 (58)	total: 815ms	remaining: 553ms
# 59:	learn: 0.7038376	test: 0.6581451	best: 0.6581451 (59)	total: 828ms	remaining: 538ms
# 60:	learn: 0.7049741	test: 0.6568941	best: 0.6581451 (59)	total: 840ms	remaining: 523ms
# 61:	learn: 0.7071367	test: 0.6600406	best: 0.6600406 (61)	total: 853ms	remaining: 509ms
# 62:	learn: 0.7093215	test: 0.6602513	best: 0.6602513 (62)	total: 868ms	remaining: 496ms
# 63:	learn: 0.7103998	test: 0.6596295	best: 0.6602513 (62)	total: 881ms	remaining: 482ms
# 64:	learn: 0.7103998	test: 0.6596295	best: 0.6602513 (62)	total: 893ms	remaining: 467ms
# 65:	learn: 0.7125462	test: 0.6590089	best: 0.6602513 (62)	total: 905ms	remaining: 453ms
# 66:	learn: 0.7152104	test: 0.6619096	best: 0.6619096 (66)	total: 919ms	remaining: 439ms
# 67:	learn: 0.7152104	test: 0.6619096	best: 0.6619096 (66)	total: 931ms	remaining: 425ms
# 68:	learn: 0.7180325	test: 0.6633552	best: 0.6633552 (68)	total: 944ms	remaining: 411ms
# 69:	learn: 0.7180325	test: 0.6633552	best: 0.6633552 (68)	total: 958ms	remaining: 397ms
# 70:	learn: 0.7208374	test: 0.6705369	best: 0.6705369 (70)	total: 991ms	remaining: 391ms
# 71:	learn: 0.7213299	test: 0.6676735	best: 0.6705369 (70)	total: 1s	remaining: 377ms
# 72:	learn: 0.7220342	test: 0.6691067	best: 0.6705369 (70)	total: 1.02s	remaining: 362ms
# 73:	learn: 0.7256504	test: 0.6694687	best: 0.6705369 (70)	total: 1.03s	remaining: 348ms
# 74:	learn: 0.7228748	test: 0.6676735	best: 0.6705369 (70)	total: 1.04s	remaining: 334ms
# 75:	learn: 0.7228748	test: 0.6676735	best: 0.6705369 (70)	total: 1.05s	remaining: 320ms
# 76:	learn: 0.7188425	test: 0.6573352	best: 0.6705369 (70)	total: 1.07s	remaining: 305ms
# 77:	learn: 0.7242592	test: 0.6676735	best: 0.6705369 (70)	total: 1.08s	remaining: 291ms
# 78:	learn: 0.7275276	test: 0.6715128	best: 0.6715128 (78)	total: 1.09s	remaining: 277ms
# 79:	learn: 0.7300867	test: 0.6751362	best: 0.6751362 (79)	total: 1.11s	remaining: 263ms
# 80:	learn: 0.7287238	test: 0.6723085	best: 0.6751362 (79)	total: 1.12s	remaining: 249ms
# 81:	learn: 0.7257893	test: 0.6629346	best: 0.6751362 (79)	total: 1.13s	remaining: 235ms
# 82:	learn: 0.7280261	test: 0.6645673	best: 0.6751362 (79)	total: 1.15s	remaining: 221ms
# 83:	learn: 0.7297400	test: 0.6639495	best: 0.6751362 (79)	total: 1.16s	remaining: 207ms
# 84:	learn: 0.7326398	test: 0.6653787	best: 0.6751362 (79)	total: 1.17s	remaining: 193ms
# 85:	learn: 0.7328105	test: 0.6653787	best: 0.6751362 (79)	total: 1.19s	remaining: 179ms
# 86:	learn: 0.7339966	test: 0.6682280	best: 0.6751362 (79)	total: 1.21s	remaining: 167ms
# 87:	learn: 0.7355159	test: 0.6684107	best: 0.6751362 (79)	total: 1.22s	remaining: 153ms
# 88:	learn: 0.7355159	test: 0.6684107	best: 0.6751362 (79)	total: 1.23s	remaining: 139ms
# 89:	learn: 0.7355159	test: 0.6684107	best: 0.6751362 (79)	total: 1.25s	remaining: 125ms
# bestTest = 0.6751361635
# bestIteration = 79
# 137:	loss: 0.6751362	best: 0.7035464 (45)	total: 2m 51s	remaining: 3m 21s
# 0:	learn: 0.0496750	test: 0.0613718	best: 0.0613718 (0)	total: 13.8ms	remaining: 1.33s
# 1:	learn: 0.1055215	test: 0.1121359	best: 0.1121359 (1)	total: 27.8ms	remaining: 1.33s
# 2:	learn: 0.1557288	test: 0.1539503	best: 0.1539503 (2)	total: 40.2ms	remaining: 1.27s
# 3:	learn: 0.1969071	test: 0.2001320	best: 0.2001320 (3)	total: 53ms	remaining: 1.24s
# 4:	learn: 0.2108138	test: 0.2120595	best: 0.2120595 (4)	total: 66.9ms	remaining: 1.24s
# 5:	learn: 0.2781378	test: 0.2680742	best: 0.2680742 (5)	total: 117ms	remaining: 1.8s
# 6:	learn: 0.2956879	test: 0.2839221	best: 0.2839221 (6)	total: 136ms	remaining: 1.77s
# 7:	learn: 0.3139275	test: 0.3128734	best: 0.3128734 (7)	total: 149ms	remaining: 1.67s
# 8:	learn: 0.3470390	test: 0.3456345	best: 0.3456345 (8)	total: 161ms	remaining: 1.59s
# 9:	learn: 0.3766927	test: 0.3737475	best: 0.3737475 (9)	total: 173ms	remaining: 1.52s
# 10:	learn: 0.3959042	test: 0.3891041	best: 0.3891041 (10)	total: 186ms	remaining: 1.47s
# 11:	learn: 0.4100233	test: 0.4028130	best: 0.4028130 (11)	total: 198ms	remaining: 1.42s
# 12:	learn: 0.4272567	test: 0.4420440	best: 0.4420440 (12)	total: 210ms	remaining: 1.37s
# 13:	learn: 0.4405307	test: 0.4458033	best: 0.4458033 (13)	total: 222ms	remaining: 1.33s
# 14:	learn: 0.4537681	test: 0.4516551	best: 0.4516551 (14)	total: 234ms	remaining: 1.3s
# 15:	learn: 0.4635418	test: 0.4684247	best: 0.4684247 (15)	total: 247ms	remaining: 1.26s
# 16:	learn: 0.4774464	test: 0.4764976	best: 0.4764976 (16)	total: 259ms	remaining: 1.23s
# 17:	learn: 0.4864469	test: 0.4855049	best: 0.4855049 (17)	total: 271ms	remaining: 1.2s
# 18:	learn: 0.5020194	test: 0.4915478	best: 0.4915478 (18)	total: 283ms	remaining: 1.18s
# 19:	learn: 0.5100946	test: 0.4974407	best: 0.4974407 (19)	total: 296ms	remaining: 1.15s
# 20:	learn: 0.5309597	test: 0.5246223	best: 0.5246223 (20)	total: 308ms	remaining: 1.13s
# 21:	learn: 0.5304763	test: 0.5246223	best: 0.5246223 (20)	total: 335ms	remaining: 1.16s
# 22:	learn: 0.5391297	test: 0.5375945	best: 0.5375945 (22)	total: 348ms	remaining: 1.14s
# 23:	learn: 0.5467556	test: 0.5394291	best: 0.5394291 (23)	total: 361ms	remaining: 1.11s
# 24:	learn: 0.5541106	test: 0.5443147	best: 0.5443147 (24)	total: 373ms	remaining: 1.09s
# 25:	learn: 0.5627525	test: 0.5485618	best: 0.5485618 (25)	total: 386ms	remaining: 1.07s
# 26:	learn: 0.5703561	test: 0.5485901	best: 0.5485901 (26)	total: 398ms	remaining: 1.05s
# 27:	learn: 0.5771415	test: 0.5503812	best: 0.5503812 (27)	total: 411ms	remaining: 1.03s
# 28:	learn: 0.5810228	test: 0.5515777	best: 0.5515777 (28)	total: 423ms	remaining: 1.01s
# 29:	learn: 0.5883931	test: 0.5598450	best: 0.5598450 (29)	total: 436ms	remaining: 988ms
# 30:	learn: 0.5977508	test: 0.5761209	best: 0.5761209 (30)	total: 449ms	remaining: 970ms
# 31:	learn: 0.6029484	test: 0.5772364	best: 0.5772364 (31)	total: 461ms	remaining: 951ms
# 32:	learn: 0.6076792	test: 0.5874711	best: 0.5874711 (32)	total: 473ms	remaining: 932ms
# 33:	learn: 0.6102462	test: 0.5874711	best: 0.5874711 (32)	total: 486ms	remaining: 915ms
# 34:	learn: 0.6180595	test: 0.6006945	best: 0.6006945 (34)	total: 500ms	remaining: 900ms
# 35:	learn: 0.6244117	test: 0.6023472	best: 0.6023472 (35)	total: 514ms	remaining: 885ms
# 36:	learn: 0.6298752	test: 0.6103179	best: 0.6103179 (36)	total: 527ms	remaining: 868ms
# 37:	learn: 0.6354397	test: 0.6096991	best: 0.6103179 (36)	total: 552ms	remaining: 872ms
# 38:	learn: 0.6390971	test: 0.6113211	best: 0.6113211 (38)	total: 564ms	remaining: 854ms
# 39:	learn: 0.6391127	test: 0.6125618	best: 0.6125618 (39)	total: 577ms	remaining: 837ms
# 40:	learn: 0.6451494	test: 0.6171493	best: 0.6171493 (40)	total: 590ms	remaining: 820ms
# 41:	learn: 0.6475553	test: 0.6187516	best: 0.6187516 (41)	total: 607ms	remaining: 809ms
# 42:	learn: 0.6521745	test: 0.6187516	best: 0.6187516 (41)	total: 620ms	remaining: 793ms
# 43:	learn: 0.6573208	test: 0.6187516	best: 0.6187516 (41)	total: 632ms	remaining: 776ms
# 44:	learn: 0.6610288	test: 0.6219452	best: 0.6219452 (44)	total: 645ms	remaining: 759ms
# 45:	learn: 0.6650355	test: 0.6267079	best: 0.6267079 (45)	total: 657ms	remaining: 743ms
# 46:	learn: 0.6681352	test: 0.6282881	best: 0.6282881 (46)	total: 670ms	remaining: 727ms
# 47:	learn: 0.6685216	test: 0.6282881	best: 0.6282881 (46)	total: 682ms	remaining: 711ms
# 48:	learn: 0.6722222	test: 0.6336180	best: 0.6336180 (48)	total: 695ms	remaining: 695ms
# 49:	learn: 0.6741331	test: 0.6329918	best: 0.6336180 (48)	total: 707ms	remaining: 679ms
# 50:	learn: 0.6778947	test: 0.6348454	best: 0.6348454 (50)	total: 720ms	remaining: 663ms
# 51:	learn: 0.6841286	test: 0.6379337	best: 0.6379337 (51)	total: 732ms	remaining: 648ms
# 52:	learn: 0.6885070	test: 0.6419118	best: 0.6419118 (52)	total: 744ms	remaining: 632ms
# 53:	learn: 0.6885070	test: 0.6419118	best: 0.6419118 (52)	total: 771ms	remaining: 628ms
# 54:	learn: 0.6921626	test: 0.6428118	best: 0.6428118 (54)	total: 784ms	remaining: 613ms
# 55:	learn: 0.6960584	test: 0.6527730	best: 0.6527730 (55)	total: 797ms	remaining: 598ms
# 56:	learn: 0.6960584	test: 0.6527730	best: 0.6527730 (55)	total: 810ms	remaining: 582ms
# 57:	learn: 0.6960584	test: 0.6527730	best: 0.6527730 (55)	total: 822ms	remaining: 567ms
# 58:	learn: 0.6998987	test: 0.6617177	best: 0.6617177 (58)	total: 834ms	remaining: 552ms
# 59:	learn: 0.7030335	test: 0.6619267	best: 0.6619267 (59)	total: 847ms	remaining: 536ms
# 60:	learn: 0.7063675	test: 0.6636044	best: 0.6636044 (60)	total: 859ms	remaining: 521ms
# 61:	learn: 0.7061416	test: 0.6621345	best: 0.6636044 (60)	total: 872ms	remaining: 506ms
# 62:	learn: 0.7086973	test: 0.6623410	best: 0.6636044 (60)	total: 884ms	remaining: 491ms
# 63:	learn: 0.7097815	test: 0.6617111	best: 0.6636044 (60)	total: 897ms	remaining: 476ms
# 64:	learn: 0.7097815	test: 0.6617111	best: 0.6636044 (60)	total: 911ms	remaining: 462ms
# 65:	learn: 0.7128303	test: 0.6625463	best: 0.6636044 (60)	total: 923ms	remaining: 448ms
# 66:	learn: 0.7144486	test: 0.6625463	best: 0.6636044 (60)	total: 936ms	remaining: 433ms
# 67:	learn: 0.7144486	test: 0.6610824	best: 0.6636044 (60)	total: 951ms	remaining: 420ms
# 68:	learn: 0.7169053	test: 0.6610824	best: 0.6636044 (60)	total: 964ms	remaining: 405ms
# 69:	learn: 0.7169053	test: 0.6640069	best: 0.6640069 (69)	total: 990ms	remaining: 396ms
# 70:	learn: 0.7193871	test: 0.6712626	best: 0.6712626 (70)	total: 1s	remaining: 382ms
# 71:	learn: 0.7211316	test: 0.6743109	best: 0.6743109 (71)	total: 1.02s	remaining: 368ms
# 72:	learn: 0.7218382	test: 0.6743109	best: 0.6743109 (71)	total: 1.03s	remaining: 353ms
# 73:	learn: 0.7225107	test: 0.6714395	best: 0.6743109 (71)	total: 1.04s	remaining: 338ms
# 74:	learn: 0.7244241	test: 0.6708089	best: 0.6743109 (71)	total: 1.06s	remaining: 324ms
# 75:	learn: 0.7244241	test: 0.6708089	best: 0.6743109 (71)	total: 1.07s	remaining: 310ms
# 76:	learn: 0.7256347	test: 0.6730481	best: 0.6743109 (71)	total: 1.08s	remaining: 295ms
# 77:	learn: 0.7258084	test: 0.6730481	best: 0.6743109 (71)	total: 1.1s	remaining: 282ms
# 78:	learn: 0.7261445	test: 0.6743109	best: 0.6743109 (71)	total: 1.12s	remaining: 270ms
# 79:	learn: 0.7261445	test: 0.6743109	best: 0.6743109 (71)	total: 1.14s	remaining: 256ms
# 80:	learn: 0.7287172	test: 0.6736789	best: 0.6743109 (71)	total: 1.15s	remaining: 241ms
# 81:	learn: 0.7293976	test: 0.6722454	best: 0.6743109 (71)	total: 1.16s	remaining: 227ms
# bestTest = 0.6743108504
# bestIteration = 71
# 138:	loss: 0.6743109	best: 0.7035464 (45)	total: 2m 52s	remaining: 3m 19s
# 0:	learn: 0.0496750	test: 0.0613718	best: 0.0613718 (0)	total: 13.5ms	remaining: 2.23s
# 1:	learn: 0.1055215	test: 0.1121359	best: 0.1121359 (1)	total: 28.5ms	remaining: 2.34s
# 2:	learn: 0.1557288	test: 0.1539503	best: 0.1539503 (2)	total: 40.7ms	remaining: 2.21s
# 3:	learn: 0.1969071	test: 0.2001320	best: 0.2001320 (3)	total: 53ms	remaining: 2.15s
# 4:	learn: 0.2108138	test: 0.2120595	best: 0.2120595 (4)	total: 65.2ms	remaining: 2.1s
# 5:	learn: 0.2274385	test: 0.2469119	best: 0.2469119 (5)	total: 77.4ms	remaining: 2.06s
# 6:	learn: 0.2386493	test: 0.2582294	best: 0.2582294 (6)	total: 89.8ms	remaining: 2.04s
# 7:	learn: 0.3034815	test: 0.3106962	best: 0.3106962 (7)	total: 102ms	remaining: 2.02s
# 8:	learn: 0.3371183	test: 0.3436112	best: 0.3436112 (8)	total: 119ms	remaining: 2.08s
# 9:	learn: 0.3672310	test: 0.3718565	best: 0.3718565 (9)	total: 132ms	remaining: 2.05s
# 10:	learn: 0.3867262	test: 0.3872779	best: 0.3872779 (10)	total: 144ms	remaining: 2.03s
# 11:	learn: 0.4010236	test: 0.4010389	best: 0.4010389 (11)	total: 157ms	remaining: 2.01s
# 12:	learn: 0.4133276	test: 0.4100831	best: 0.4100831 (12)	total: 169ms	remaining: 1.99s
# 13:	learn: 0.4269561	test: 0.4140601	best: 0.4140601 (13)	total: 182ms	remaining: 1.97s
# 14:	learn: 0.4437211	test: 0.4527309	best: 0.4527309 (14)	total: 194ms	remaining: 1.96s
# 15:	learn: 0.4541971	test: 0.4695283	best: 0.4695283 (15)	total: 207ms	remaining: 1.94s
# 16:	learn: 0.4683494	test: 0.4776074	best: 0.4776074 (16)	total: 235ms	remaining: 2.06s
# 17:	learn: 0.4774933	test: 0.4866256	best: 0.4866256 (17)	total: 248ms	remaining: 2.04s
# 18:	learn: 0.4933378	test: 0.4926659	best: 0.4926659 (18)	total: 261ms	remaining: 2.02s
# 19:	learn: 0.5015290	test: 0.4985678	best: 0.4985678 (19)	total: 273ms	remaining: 1.99s
# 20:	learn: 0.5121457	test: 0.5063655	best: 0.5063655 (20)	total: 286ms	remaining: 1.98s
# 21:	learn: 0.5111410	test: 0.5044237	best: 0.5063655 (20)	total: 299ms	remaining: 1.96s
# 22:	learn: 0.5185167	test: 0.5079500	best: 0.5079500 (22)	total: 312ms	remaining: 1.94s
# 23:	learn: 0.5298439	test: 0.5150314	best: 0.5150314 (23)	total: 324ms	remaining: 1.92s
# 24:	learn: 0.5393627	test: 0.5220250	best: 0.5220250 (24)	total: 337ms	remaining: 1.9s
# 25:	learn: 0.5478198	test: 0.5270686	best: 0.5270686 (25)	total: 350ms	remaining: 1.88s
# 26:	learn: 0.5552003	test: 0.5271952	best: 0.5271952 (26)	total: 362ms	remaining: 1.86s
# 27:	learn: 0.5628163	test: 0.5302099	best: 0.5302099 (27)	total: 374ms	remaining: 1.84s
# 28:	learn: 0.5701813	test: 0.5424952	best: 0.5424952 (28)	total: 387ms	remaining: 1.83s
# 29:	learn: 0.5775881	test: 0.5473486	best: 0.5473486 (29)	total: 399ms	remaining: 1.81s
# 30:	learn: 0.5865694	test: 0.5628311	best: 0.5628311 (30)	total: 411ms	remaining: 1.79s
# 31:	learn: 0.5920479	test: 0.5639941	best: 0.5639941 (31)	total: 424ms	remaining: 1.77s
# 32:	learn: 0.5993016	test: 0.5703982	best: 0.5703982 (32)	total: 449ms	remaining: 1.81s
# 33:	learn: 0.5991893	test: 0.5703982	best: 0.5703982 (32)	total: 461ms	remaining: 1.79s
# 34:	learn: 0.6054333	test: 0.5789525	best: 0.5789525 (34)	total: 474ms	remaining: 1.77s
# 35:	learn: 0.6110224	test: 0.5806644	best: 0.5806644 (35)	total: 487ms	remaining: 1.76s
# 36:	learn: 0.6218248	test: 0.5932684	best: 0.5932684 (36)	total: 501ms	remaining: 1.75s
# 37:	learn: 0.6275623	test: 0.5949290	best: 0.5949290 (37)	total: 515ms	remaining: 1.73s
# 38:	learn: 0.6316828	test: 0.5965856	best: 0.5965856 (38)	total: 528ms	remaining: 1.72s
# 39:	learn: 0.6319308	test: 0.5978092	best: 0.5978092 (39)	total: 541ms	remaining: 1.7s
# 40:	learn: 0.6376519	test: 0.6009192	best: 0.6009192 (40)	total: 557ms	remaining: 1.7s
# 41:	learn: 0.6417832	test: 0.6107027	best: 0.6107027 (41)	total: 569ms	remaining: 1.68s
# 42:	learn: 0.6470189	test: 0.6107027	best: 0.6107027 (41)	total: 583ms	remaining: 1.67s
# 43:	learn: 0.6498871	test: 0.6100854	best: 0.6107027 (41)	total: 601ms	remaining: 1.67s
# 44:	learn: 0.6550567	test: 0.6094695	best: 0.6107027 (41)	total: 614ms	remaining: 1.65s
# 45:	learn: 0.6611969	test: 0.6126966	best: 0.6126966 (45)	total: 626ms	remaining: 1.63s
# 46:	learn: 0.6639380	test: 0.6143046	best: 0.6143046 (46)	total: 638ms	remaining: 1.62s
# 47:	learn: 0.6639380	test: 0.6143046	best: 0.6143046 (46)	total: 666ms	remaining: 1.64s
# 48:	learn: 0.6676982	test: 0.6198088	best: 0.6198088 (48)	total: 678ms	remaining: 1.62s
# 49:	learn: 0.6744004	test: 0.6332789	best: 0.6332789 (49)	total: 691ms	remaining: 1.6s
# 50:	learn: 0.6786465	test: 0.6341975	best: 0.6341975 (50)	total: 703ms	remaining: 1.59s
# 51:	learn: 0.6826097	test: 0.6448641	best: 0.6448641 (51)	total: 716ms	remaining: 1.57s
# 52:	learn: 0.6856331	test: 0.6463744	best: 0.6463744 (52)	total: 728ms	remaining: 1.55s
# 53:	learn: 0.6910568	test: 0.6502579	best: 0.6502579 (53)	total: 740ms	remaining: 1.53s
# 54:	learn: 0.6953266	test: 0.6541083	best: 0.6541083 (54)	total: 752ms	remaining: 1.52s
# 55:	learn: 0.6954960	test: 0.6541083	best: 0.6541083 (54)	total: 765ms	remaining: 1.5s
# 56:	learn: 0.6954960	test: 0.6541083	best: 0.6541083 (54)	total: 777ms	remaining: 1.49s
# 57:	learn: 0.6976891	test: 0.6570759	best: 0.6570759 (57)	total: 790ms	remaining: 1.47s
# 58:	learn: 0.7007635	test: 0.6602433	best: 0.6602433 (58)	total: 803ms	remaining: 1.46s
# 59:	learn: 0.7013958	test: 0.6621345	best: 0.6621345 (59)	total: 816ms	remaining: 1.44s
# 60:	learn: 0.7025459	test: 0.6608725	best: 0.6621345 (59)	total: 841ms	remaining: 1.45s
# 61:	learn: 0.7043664	test: 0.6640069	best: 0.6640069 (61)	total: 859ms	remaining: 1.44s
# 62:	learn: 0.7074577	test: 0.6677388	best: 0.6677388 (62)	total: 886ms	remaining: 1.45s
# 63:	learn: 0.7078145	test: 0.6677388	best: 0.6677388 (62)	total: 898ms	remaining: 1.43s
# 64:	learn: 0.7078145	test: 0.6677388	best: 0.6677388 (62)	total: 911ms	remaining: 1.42s
# 65:	learn: 0.7098452	test: 0.6671091	best: 0.6677388 (62)	total: 923ms	remaining: 1.4s
# 66:	learn: 0.7046658	test: 0.6591850	best: 0.6677388 (62)	total: 936ms	remaining: 1.38s
# 67:	learn: 0.7046658	test: 0.6591850	best: 0.6677388 (62)	total: 948ms	remaining: 1.37s
# 68:	learn: 0.7075920	test: 0.6606613	best: 0.6677388 (62)	total: 968ms	remaining: 1.36s
# 69:	learn: 0.7068766	test: 0.6621345	best: 0.6677388 (62)	total: 980ms	remaining: 1.34s
# 70:	learn: 0.7097975	test: 0.6694518	best: 0.6694518 (70)	total: 994ms	remaining: 1.33s
# 71:	learn: 0.7128303	test: 0.6698178	best: 0.6698178 (71)	total: 1.01s	remaining: 1.31s
# 72:	learn: 0.7137320	test: 0.6712626	best: 0.6712626 (72)	total: 1.02s	remaining: 1.3s
# 73:	learn: 0.7142289	test: 0.6683698	best: 0.6712626 (72)	total: 1.03s	remaining: 1.28s
# 74:	learn: 0.7165441	test: 0.6691861	best: 0.6712626 (72)	total: 1.04s	remaining: 1.26s
# 75:	learn: 0.7165441	test: 0.6691861	best: 0.6712626 (72)	total: 1.05s	remaining: 1.25s
# 76:	learn: 0.7186635	test: 0.6685557	best: 0.6712626 (72)	total: 1.07s	remaining: 1.23s
# 77:	learn: 0.7202444	test: 0.6699991	best: 0.6712626 (72)	total: 1.08s	remaining: 1.22s
# 78:	learn: 0.7207621	test: 0.6699991	best: 0.6712626 (72)	total: 1.1s	remaining: 1.21s
# 79:	learn: 0.7226745	test: 0.6716153	best: 0.6716153 (79)	total: 1.11s	remaining: 1.2s
# 80:	learn: 0.7230209	test: 0.6716153	best: 0.6716153 (79)	total: 1.13s	remaining: 1.18s
# 81:	learn: 0.7251041	test: 0.6709864	best: 0.6716153 (79)	total: 1.14s	remaining: 1.17s
# 82:	learn: 0.7254487	test: 0.6709864	best: 0.6716153 (79)	total: 1.15s	remaining: 1.15s
# 83:	learn: 0.7271689	test: 0.6703587	best: 0.6716153 (79)	total: 1.16s	remaining: 1.14s
# 84:	learn: 0.7300841	test: 0.6717902	best: 0.6717902 (84)	total: 1.18s	remaining: 1.12s
# 85:	learn: 0.7356693	test: 0.6832712	best: 0.6832712 (85)	total: 1.19s	remaining: 1.11s
# 86:	learn: 0.7356693	test: 0.6832712	best: 0.6832712 (85)	total: 1.21s	remaining: 1.09s
# 87:	learn: 0.7388404	test: 0.6848054	best: 0.6848054 (87)	total: 1.22s	remaining: 1.08s
# 88:	learn: 0.7395023	test: 0.6848054	best: 0.6848054 (87)	total: 1.23s	remaining: 1.06s
# 89:	learn: 0.7421334	test: 0.6893358	best: 0.6893358 (89)	total: 1.24s	remaining: 1.05s
# 90:	learn: 0.7428126	test: 0.6879613	best: 0.6893358 (89)	total: 1.26s	remaining: 1.03s
# 91:	learn: 0.7441273	test: 0.6873355	best: 0.6893358 (89)	total: 1.27s	remaining: 1.02s
# 92:	learn: 0.7449078	test: 0.6867110	best: 0.6893358 (89)	total: 1.29s	remaining: 1.02s
# 93:	learn: 0.7449078	test: 0.6867110	best: 0.6893358 (89)	total: 1.31s	remaining: 1s
# 94:	learn: 0.7449078	test: 0.6867110	best: 0.6893358 (89)	total: 1.32s	remaining: 987ms
# 95:	learn: 0.7449078	test: 0.6867110	best: 0.6893358 (89)	total: 1.34s	remaining: 976ms
# 96:	learn: 0.7452264	test: 0.6880843	best: 0.6893358 (89)	total: 1.35s	remaining: 961ms
# 97:	learn: 0.7455444	test: 0.6894548	best: 0.6894548 (97)	total: 1.36s	remaining: 946ms
# 98:	learn: 0.7457032	test: 0.6894548	best: 0.6894548 (97)	total: 1.38s	remaining: 931ms
# 99:	learn: 0.7457032	test: 0.6894548	best: 0.6894548 (97)	total: 1.39s	remaining: 917ms
# 100:	learn: 0.7457032	test: 0.6894548	best: 0.6894548 (97)	total: 1.4s	remaining: 902ms
# 101:	learn: 0.7457032	test: 0.6894548	best: 0.6894548 (97)	total: 1.41s	remaining: 887ms
# 102:	learn: 0.7447482	test: 0.6864560	best: 0.6894548 (97)	total: 1.43s	remaining: 872ms
# 103:	learn: 0.7465281	test: 0.6900805	best: 0.6900805 (103)	total: 1.44s	remaining: 858ms
# 104:	learn: 0.7474985	test: 0.6895731	best: 0.6900805 (103)	total: 1.45s	remaining: 844ms
# 105:	learn: 0.7474985	test: 0.6895731	best: 0.6900805 (103)	total: 1.47s	remaining: 830ms
# 106:	learn: 0.7473643	test: 0.6873355	best: 0.6900805 (103)	total: 1.48s	remaining: 816ms
# 107:	learn: 0.7473643	test: 0.6873355	best: 0.6900805 (103)	total: 1.51s	remaining: 810ms
# 108:	learn: 0.7484909	test: 0.6909366	best: 0.6909366 (108)	total: 1.52s	remaining: 795ms
# 109:	learn: 0.7494568	test: 0.6922974	best: 0.6922974 (109)	total: 1.53s	remaining: 781ms
# 110:	learn: 0.7494568	test: 0.6922974	best: 0.6922974 (109)	total: 1.55s	remaining: 766ms
# 111:	learn: 0.7494568	test: 0.6922974	best: 0.6922974 (109)	total: 1.56s	remaining: 752ms
# ...
# 55:	learn: 0.7698509	test: 0.7154428	best: 0.7160021 (52)	total: 792ms	remaining: 1.31s
# 56:	learn: 0.7710239	test: 0.7127734	best: 0.7160021 (52)	total: 805ms	remaining: 1.3s
# 57:	learn: 0.7733573	test: 0.7135515	best: 0.7160021 (52)	total: 818ms	remaining: 1.28s
# 58:	learn: 0.7742849	test: 0.7135515	best: 0.7160021 (52)	total: 831ms	remaining: 1.27s
# 59:	learn: 0.7738137	test: 0.7135515	best: 0.7160021 (52)	total: 857ms	remaining: 1.27s
# 60:	learn: 0.7739608	test: 0.7135515	best: 0.7160021 (52)	total: 885ms	remaining: 1.28s
# 61:	learn: 0.7756944	test: 0.7156563	best: 0.7160021 (52)	total: 898ms	remaining: 1.26s
# 62:	learn: 0.7756944	test: 0.7156563	best: 0.7160021 (52)	total: 915ms	remaining: 1.25s
# bestTest = 0.7160021111
# bestIteration = 52
# Training on fold [3/5]
# 0:	learn: 0.1091066	test: 0.1049292	best: 0.1049292 (0)	total: 13.8ms	remaining: 2.05s
# 1:	learn: 0.1677578	test: 0.1837874	best: 0.1837874 (1)	total: 28.5ms	remaining: 2.1s
# 2:	learn: 0.2431176	test: 0.2325423	best: 0.2325423 (2)	total: 41.3ms	remaining: 2.01s
# 3:	learn: 0.2958656	test: 0.2893700	best: 0.2893700 (3)	total: 53.9ms	remaining: 1.95s
# 4:	learn: 0.3215057	test: 0.3160584	best: 0.3160584 (4)	total: 66.4ms	remaining: 1.91s
# 5:	learn: 0.3828863	test: 0.3850275	best: 0.3850275 (5)	total: 79.2ms	remaining: 1.89s
# 6:	learn: 0.3935391	test: 0.3917870	best: 0.3917870 (6)	total: 92.1ms	remaining: 1.87s
# 7:	learn: 0.4453353	test: 0.4435802	best: 0.4435802 (7)	total: 105ms	remaining: 1.84s
# 8:	learn: 0.4811012	test: 0.4915826	best: 0.4915826 (8)	total: 117ms	remaining: 1.82s
# 9:	learn: 0.5019668	test: 0.5047631	best: 0.5047631 (9)	total: 130ms	remaining: 1.81s
# 10:	learn: 0.5172970	test: 0.5142160	best: 0.5142160 (10)	total: 143ms	remaining: 1.79s
# 11:	learn: 0.5234123	test: 0.5219654	best: 0.5219654 (11)	total: 155ms	remaining: 1.77s
# 12:	learn: 0.5475042	test: 0.5458377	best: 0.5458377 (12)	total: 168ms	remaining: 1.76s
# 13:	learn: 0.5678877	test: 0.5602768	best: 0.5602768 (13)	total: 181ms	remaining: 1.74s
# 14:	learn: 0.5829616	test: 0.5623014	best: 0.5623014 (14)	total: 193ms	remaining: 1.73s
# 15:	learn: 0.5883254	test: 0.5659014	best: 0.5659014 (15)	total: 206ms	remaining: 1.71s
# 16:	learn: 0.6025365	test: 0.5795815	best: 0.5795815 (16)	total: 231ms	remaining: 1.79s
# 17:	learn: 0.6176373	test: 0.5883228	best: 0.5883228 (17)	total: 243ms	remaining: 1.77s
# 18:	learn: 0.6287560	test: 0.5987300	best: 0.5987300 (18)	total: 256ms	remaining: 1.75s
# 19:	learn: 0.6346107	test: 0.6016751	best: 0.6016751 (19)	total: 268ms	remaining: 1.73s
# 20:	learn: 0.6397183	test: 0.6044856	best: 0.6044856 (20)	total: 281ms	remaining: 1.71s
# 21:	learn: 0.6457424	test: 0.6056108	best: 0.6056108 (21)	total: 294ms	remaining: 1.7s
# 22:	learn: 0.6509782	test: 0.6133558	best: 0.6133558 (22)	total: 307ms	remaining: 1.68s
# 23:	learn: 0.6581361	test: 0.6215484	best: 0.6215484 (23)	total: 319ms	remaining: 1.66s
# 24:	learn: 0.6606047	test: 0.6215173	best: 0.6215484 (23)	total: 332ms	remaining: 1.65s
# 25:	learn: 0.6656167	test: 0.6279774	best: 0.6279774 (25)	total: 344ms	remaining: 1.63s
# 26:	learn: 0.6737949	test: 0.6385790	best: 0.6385790 (26)	total: 356ms	remaining: 1.61s
# 27:	learn: 0.6807089	test: 0.6384843	best: 0.6385790 (26)	total: 369ms	remaining: 1.59s
# 28:	learn: 0.6810855	test: 0.6384843	best: 0.6385790 (26)	total: 381ms	remaining: 1.58s
# 29:	learn: 0.6842679	test: 0.6361809	best: 0.6385790 (26)	total: 393ms	remaining: 1.56s
# 30:	learn: 0.6902996	test: 0.6465015	best: 0.6465015 (30)	total: 406ms	remaining: 1.54s
# 31:	learn: 0.6979954	test: 0.6504149	best: 0.6504149 (31)	total: 418ms	remaining: 1.53s
# 32:	learn: 0.7028403	test: 0.6598848	best: 0.6598848 (32)	total: 443ms	remaining: 1.56s
# 33:	learn: 0.7048532	test: 0.6606540	best: 0.6606540 (33)	total: 457ms	remaining: 1.54s
# 34:	learn: 0.7091635	test: 0.6675047	best: 0.6675047 (34)	total: 469ms	remaining: 1.53s
# 35:	learn: 0.7144915	test: 0.6771743	best: 0.6771743 (35)	total: 483ms	remaining: 1.51s
# 36:	learn: 0.7217674	test: 0.6918001	best: 0.6918001 (36)	total: 495ms	remaining: 1.5s
# 37:	learn: 0.7283416	test: 0.6932150	best: 0.6932150 (37)	total: 508ms	remaining: 1.48s
# 38:	learn: 0.7300324	test: 0.6943331	best: 0.6943331 (38)	total: 521ms	remaining: 1.47s
# 39:	learn: 0.7303263	test: 0.6934956	best: 0.6943331 (38)	total: 533ms	remaining: 1.45s
# 40:	learn: 0.7327395	test: 0.6929369	best: 0.6943331 (38)	total: 546ms	remaining: 1.44s
# 41:	learn: 0.7316229	test: 0.6904240	best: 0.6943331 (38)	total: 559ms	remaining: 1.42s
# 42:	learn: 0.7345100	test: 0.6932173	best: 0.6943331 (38)	total: 571ms	remaining: 1.41s
# 43:	learn: 0.7337328	test: 0.6932173	best: 0.6943331 (38)	total: 584ms	remaining: 1.39s
# 44:	learn: 0.7390142	test: 0.7007087	best: 0.7007087 (44)	total: 597ms	remaining: 1.38s
# 45:	learn: 0.7439990	test: 0.7001088	best: 0.7007087 (44)	total: 615ms	remaining: 1.38s
# 46:	learn: 0.7446245	test: 0.7001088	best: 0.7007087 (44)	total: 628ms	remaining: 1.36s
# 47:	learn: 0.7449547	test: 0.7001088	best: 0.7007087 (44)	total: 651ms	remaining: 1.37s
# 48:	learn: 0.7479845	test: 0.7066072	best: 0.7066072 (48)	total: 667ms	remaining: 1.36s
# 49:	learn: 0.7485251	test: 0.7060511	best: 0.7066072 (48)	total: 680ms	remaining: 1.35s
# 50:	learn: 0.7510533	test: 0.7089806	best: 0.7089806 (50)	total: 693ms	remaining: 1.33s
# 51:	learn: 0.7510533	test: 0.7095363	best: 0.7095363 (51)	total: 706ms	remaining: 1.32s
# 52:	learn: 0.7510227	test: 0.7095363	best: 0.7095363 (51)	total: 719ms	remaining: 1.3s
# 53:	learn: 0.7532710	test: 0.7103213	best: 0.7103213 (53)	total: 733ms	remaining: 1.29s
# 54:	learn: 0.7538013	test: 0.7143267	best: 0.7143267 (54)	total: 764ms	remaining: 1.31s
# 55:	learn: 0.7543303	test: 0.7132141	best: 0.7143267 (54)	total: 785ms	remaining: 1.3s
# 56:	learn: 0.7546611	test: 0.7132141	best: 0.7143267 (54)	total: 801ms	remaining: 1.29s
# 57:	learn: 0.7559588	test: 0.7164256	best: 0.7164256 (57)	total: 820ms	remaining: 1.29s
# 58:	learn: 0.7575507	test: 0.7175417	best: 0.7175417 (58)	total: 837ms	remaining: 1.28s
# 59:	learn: 0.7606522	test: 0.7254484	best: 0.7254484 (59)	total: 856ms	remaining: 1.27s
# 60:	learn: 0.7609736	test: 0.7254484	best: 0.7254484 (59)	total: 873ms	remaining: 1.26s
# 61:	learn: 0.7619835	test: 0.7280624	best: 0.7280624 (61)	total: 889ms	remaining: 1.25s
# 62:	learn: 0.7619835	test: 0.7280624	best: 0.7280624 (61)	total: 905ms	remaining: 1.23s
# 63:	learn: 0.7629440	test: 0.7280624	best: 0.7280624 (61)	total: 930ms	remaining: 1.24s
# 64:	learn: 0.7655191	test: 0.7306656	best: 0.7306656 (64)	total: 950ms	remaining: 1.23s
# 65:	learn: 0.7660684	test: 0.7295407	best: 0.7306656 (64)	total: 970ms	remaining: 1.22s
# 66:	learn: 0.7652217	test: 0.7317941	best: 0.7317941 (66)	total: 986ms	remaining: 1.21s
# 67:	learn: 0.7652217	test: 0.7317941	best: 0.7317941 (66)	total: 1.03s	remaining: 1.22s
# 68:	learn: 0.7652217	test: 0.7317941	best: 0.7317941 (66)	total: 1.07s	remaining: 1.25s
# 69:	learn: 0.7652217	test: 0.7317941	best: 0.7317941 (66)	total: 1.13s	remaining: 1.28s
# 70:	learn: 0.7656471	test: 0.7303193	best: 0.7317941 (66)	total: 1.19s	remaining: 1.31s
# 71:	learn: 0.7666828	test: 0.7293654	best: 0.7317941 (66)	total: 1.25s	remaining: 1.33s
# 72:	learn: 0.7682292	test: 0.7313999	best: 0.7317941 (66)	total: 1.31s	remaining: 1.36s
# 73:	learn: 0.7682292	test: 0.7313999	best: 0.7317941 (66)	total: 1.37s	remaining: 1.38s
# 74:	learn: 0.7677439	test: 0.7313999	best: 0.7317941 (66)	total: 1.43s	remaining: 1.41s
# 75:	learn: 0.7682292	test: 0.7365624	best: 0.7365624 (75)	total: 1.49s	remaining: 1.43s
# 76:	learn: 0.7682292	test: 0.7365624	best: 0.7365624 (75)	total: 1.55s	remaining: 1.45s
# 77:	learn: 0.7719045	test: 0.7404067	best: 0.7404067 (77)	total: 1.61s	remaining: 1.46s
# 78:	learn: 0.7728793	test: 0.7436612	best: 0.7436612 (78)	total: 1.67s	remaining: 1.48s
# 79:	learn: 0.7727145	test: 0.7436612	best: 0.7436612 (78)	total: 1.71s	remaining: 1.48s
# 80:	learn: 0.7730916	test: 0.7426702	best: 0.7436612 (78)	total: 1.73s	remaining: 1.46s
# 81:	learn: 0.7754974	test: 0.7428089	best: 0.7436612 (78)	total: 1.77s	remaining: 1.45s
# 82:	learn: 0.7754974	test: 0.7428089	best: 0.7436612 (78)	total: 1.8s	remaining: 1.43s
# 83:	learn: 0.7762119	test: 0.7428089	best: 0.7436612 (78)	total: 1.82s	remaining: 1.41s
# 84:	learn: 0.7773590	test: 0.7485240	best: 0.7485240 (84)	total: 1.84s	remaining: 1.38s
# 85:	learn: 0.7787575	test: 0.7510170	best: 0.7510170 (85)	total: 1.85s	remaining: 1.36s
# 86:	learn: 0.7795237	test: 0.7510170	best: 0.7510170 (85)	total: 1.87s	remaining: 1.33s
# 87:	learn: 0.7804490	test: 0.7528242	best: 0.7528242 (87)	total: 1.89s	remaining: 1.31s
# 88:	learn: 0.7804490	test: 0.7528242	best: 0.7528242 (87)	total: 1.91s	remaining: 1.29s
# 89:	learn: 0.7804490	test: 0.7528242	best: 0.7528242 (87)	total: 1.93s	remaining: 1.26s
# 90:	learn: 0.7810652	test: 0.7528242	best: 0.7528242 (87)	total: 1.95s	remaining: 1.24s
# 91:	learn: 0.7829193	test: 0.7528242	best: 0.7528242 (87)	total: 1.96s	remaining: 1.22s
# 92:	learn: 0.7829193	test: 0.7528242	best: 0.7528242 (87)	total: 2s	remaining: 1.21s
# 93:	learn: 0.7829193	test: 0.7528242	best: 0.7528242 (87)	total: 2.03s	remaining: 1.19s
# 94:	learn: 0.7829287	test: 0.7516963	best: 0.7528242 (87)	total: 2.04s	remaining: 1.16s
# 95:	learn: 0.7844005	test: 0.7447657	best: 0.7528242 (87)	total: 2.06s	remaining: 1.14s
# 96:	learn: 0.7847076	test: 0.7447657	best: 0.7528242 (87)	total: 2.08s	remaining: 1.12s
# 97:	learn: 0.7851720	test: 0.7472737	best: 0.7528242 (87)	total: 2.13s	remaining: 1.11s
# bestTest = 0.7528242058
# bestIteration = 87
# Training on fold [4/5]
# 0:	learn: 0.1065094	test: 0.1153153	best: 0.1153153 (0)	total: 57.3ms	remaining: 8.49s
# 1:	learn: 0.1801229	test: 0.1736070	best: 0.1736070 (1)	total: 113ms	remaining: 8.28s
# 2:	learn: 0.2431036	test: 0.2550652	best: 0.2550652 (2)	total: 167ms	remaining: 8.15s
# 3:	learn: 0.3097114	test: 0.3069355	best: 0.3069355 (3)	total: 223ms	remaining: 8.09s
# 4:	learn: 0.3547223	test: 0.3513729	best: 0.3513729 (4)	total: 295ms	remaining: 8.51s
# 5:	learn: 0.3666106	test: 0.3613862	best: 0.3613862 (5)	total: 352ms	remaining: 8.38s
# 6:	learn: 0.4155868	test: 0.4420009	best: 0.4420009 (6)	total: 409ms	remaining: 8.29s
# 7:	learn: 0.4470244	test: 0.4657499	best: 0.4657499 (7)	total: 464ms	remaining: 8.19s
# 8:	learn: 0.4739877	test: 0.4848407	best: 0.4848407 (8)	total: 541ms	remaining: 8.42s
# 9:	learn: 0.4914255	test: 0.4905366	best: 0.4905366 (9)	total: 599ms	remaining: 8.33s
# 10:	learn: 0.5081616	test: 0.5042853	best: 0.5042853 (10)	total: 656ms	remaining: 8.22s
# 11:	learn: 0.5174538	test: 0.5202472	best: 0.5202472 (11)	total: 713ms	remaining: 8.13s
# 12:	learn: 0.5316457	test: 0.5261454	best: 0.5261454 (12)	total: 787ms	remaining: 8.23s
# 13:	learn: 0.5515583	test: 0.5356740	best: 0.5356740 (13)	total: 845ms	remaining: 8.15s
# 14:	learn: 0.5663873	test: 0.5441545	best: 0.5441545 (14)	total: 904ms	remaining: 8.08s
# 15:	learn: 0.5750706	test: 0.5487459	best: 0.5487459 (15)	total: 962ms	remaining: 8s
# 16:	learn: 0.5872839	test: 0.5654553	best: 0.5654553 (16)	total: 1s	remaining: 7.8s
# 17:	learn: 0.6022494	test: 0.5819144	best: 0.5819144 (17)	total: 1.02s	remaining: 7.45s
# 18:	learn: 0.6129702	test: 0.5825939	best: 0.5825939 (18)	total: 1.04s	remaining: 7.13s
# 19:	learn: 0.6215234	test: 0.5943858	best: 0.5943858 (19)	total: 1.06s	remaining: 6.84s
# 20:	learn: 0.6387260	test: 0.6223423	best: 0.6223423 (20)	total: 1.08s	remaining: 6.56s
# 21:	learn: 0.6451410	test: 0.6240149	best: 0.6240149 (21)	total: 1.09s	remaining: 6.3s
# 22:	learn: 0.6556924	test: 0.6420365	best: 0.6420365 (22)	total: 1.1s	remaining: 6.06s
# 23:	learn: 0.6708301	test: 0.6600869	best: 0.6600869 (23)	total: 1.13s	remaining: 5.91s
# 24:	learn: 0.6744000	test: 0.6583576	best: 0.6600869 (23)	total: 1.15s	remaining: 5.7s
# 25:	learn: 0.6774151	test: 0.6593357	best: 0.6600869 (23)	total: 1.16s	remaining: 5.5s
# 26:	learn: 0.6865602	test: 0.6591633	best: 0.6600869 (23)	total: 1.18s	remaining: 5.32s
# 27:	learn: 0.6953222	test: 0.6666461	best: 0.6666461 (27)	total: 1.19s	remaining: 5.15s
# 28:	learn: 0.7043367	test: 0.6698393	best: 0.6698393 (28)	total: 1.22s	remaining: 5.05s
# 29:	learn: 0.7044859	test: 0.6698393	best: 0.6698393 (28)	total: 1.23s	remaining: 4.89s
# 30:	learn: 0.7101105	test: 0.6722708	best: 0.6722708 (30)	total: 1.25s	remaining: 4.75s
# 31:	learn: 0.7099875	test: 0.6709833	best: 0.6722708 (30)	total: 1.26s	remaining: 4.62s
# 32:	learn: 0.7137625	test: 0.6743392	best: 0.6743392 (32)	total: 1.28s	remaining: 4.49s
# 33:	learn: 0.7180449	test: 0.6817717	best: 0.6817717 (33)	total: 1.29s	remaining: 4.37s
# 34:	learn: 0.7234135	test: 0.6856141	best: 0.6856141 (34)	total: 1.3s	remaining: 4.25s
# 35:	learn: 0.7270668	test: 0.6835690	best: 0.6856141 (34)	total: 1.32s	remaining: 4.15s
# 36:	learn: 0.7316938	test: 0.6894509	best: 0.6894509 (36)	total: 1.34s	remaining: 4.05s
# 37:	learn: 0.7347200	test: 0.6903233	best: 0.6903233 (37)	total: 1.35s	remaining: 3.95s
# 38:	learn: 0.7347200	test: 0.6917660	best: 0.6917660 (38)	total: 1.36s	remaining: 3.85s
# 39:	learn: 0.7364694	test: 0.6903233	best: 0.6917660 (38)	total: 1.38s	remaining: 3.76s
# 40:	learn: 0.7390008	test: 0.6917660	best: 0.6917660 (38)	total: 1.39s	remaining: 3.67s
# 41:	learn: 0.7421623	test: 0.6983555	best: 0.6983555 (41)	total: 1.41s	remaining: 3.58s
# 42:	learn: 0.7423868	test: 0.6983555	best: 0.6983555 (41)	total: 1.43s	remaining: 3.53s
# 43:	learn: 0.7454459	test: 0.7017250	best: 0.7017250 (43)	total: 1.45s	remaining: 3.46s
# 44:	learn: 0.7485520	test: 0.7047922	best: 0.7047922 (44)	total: 1.46s	remaining: 3.38s
# 45:	learn: 0.7485520	test: 0.7047922	best: 0.7047922 (44)	total: 1.48s	remaining: 3.31s
# 46:	learn: 0.7489694	test: 0.7039645	best: 0.7047922 (44)	total: 1.49s	remaining: 3.24s
# 47:	learn: 0.7519027	test: 0.7092182	best: 0.7092182 (47)	total: 1.5s	remaining: 3.17s
# 48:	learn: 0.7519027	test: 0.7092182	best: 0.7092182 (47)	total: 1.52s	remaining: 3.1s
# 49:	learn: 0.7547324	test: 0.7099284	best: 0.7099284 (49)	total: 1.53s	remaining: 3.03s
# 50:	learn: 0.7558216	test: 0.7101626	best: 0.7101626 (50)	total: 1.54s	remaining: 2.97s
# 51:	learn: 0.7587668	test: 0.7098286	best: 0.7101626 (50)	total: 1.56s	remaining: 2.9s
# 52:	learn: 0.7602082	test: 0.7125565	best: 0.7125565 (52)	total: 1.57s	remaining: 2.84s
# 53:	learn: 0.7627044	test: 0.7108579	best: 0.7125565 (52)	total: 1.58s	remaining: 2.79s
# 54:	learn: 0.7651372	test: 0.7108579	best: 0.7125565 (52)	total: 1.6s	remaining: 2.73s
# 55:	learn: 0.7651372	test: 0.7102935	best: 0.7125565 (52)	total: 1.61s	remaining: 2.67s
# 56:	learn: 0.7677050	test: 0.7143581	best: 0.7143581 (56)	total: 1.62s	remaining: 2.62s
# 57:	learn: 0.7677050	test: 0.7143581	best: 0.7143581 (56)	total: 1.65s	remaining: 2.58s
# 58:	learn: 0.7717556	test: 0.7170536	best: 0.7170536 (58)	total: 1.66s	remaining: 2.54s
# 59:	learn: 0.7727466	test: 0.7180401	best: 0.7180401 (59)	total: 1.68s	remaining: 2.48s
# 60:	learn: 0.7727466	test: 0.7180401	best: 0.7180401 (59)	total: 1.69s	remaining: 2.44s
# 61:	learn: 0.7736706	test: 0.7188120	best: 0.7188120 (61)	total: 1.7s	remaining: 2.39s
# 62:	learn: 0.7746685	test: 0.7195811	best: 0.7195811 (62)	total: 1.71s	remaining: 2.34s
# 63:	learn: 0.7773330	test: 0.7218717	best: 0.7218717 (63)	total: 1.73s	remaining: 2.29s
# 64:	learn: 0.7782379	test: 0.7218717	best: 0.7218717 (63)	total: 1.74s	remaining: 2.25s
# 65:	learn: 0.7782628	test: 0.7201882	best: 0.7218717 (63)	total: 1.75s	remaining: 2.2s
# 66:	learn: 0.7785725	test: 0.7201882	best: 0.7218717 (63)	total: 1.76s	remaining: 2.16s
# 67:	learn: 0.7791676	test: 0.7188663	best: 0.7218717 (63)	total: 1.78s	remaining: 2.12s
# 68:	learn: 0.7791676	test: 0.7188663	best: 0.7218717 (63)	total: 1.79s	remaining: 2.08s
# 69:	learn: 0.7799582	test: 0.7183073	best: 0.7218717 (63)	total: 1.8s	remaining: 2.03s
# 70:	learn: 0.7807030	test: 0.7177492	best: 0.7218717 (63)	total: 1.81s	remaining: 1.99s
# 71:	learn: 0.7808521	test: 0.7177492	best: 0.7218717 (63)	total: 1.83s	remaining: 1.96s
# 72:	learn: 0.7825835	test: 0.7198303	best: 0.7218717 (63)	total: 1.86s	remaining: 1.93s
# 73:	learn: 0.7825835	test: 0.7198303	best: 0.7218717 (63)	total: 1.87s	remaining: 1.9s
# bestTest = 0.7218716533
# bestIteration = 63

# %%
# Examining the parameters
catboost_clf.get_params()
# Out:
# {'loss_function': 'Logloss',
#  'eval_metric': 'F1',
#  'task_type': 'GPU',
#  'random_state': 42,
#  'early_stopping_rounds': 10,
#  'min_data_in_leaf': 27,
#  'depth': 2,
#  'iterations': 149,
#  'learning_rate': 0.9976412172247356,
#  'l2_leaf_reg': 4.3525809955619685,
#  'auto_class_weights': 'Balanced'}

# %%
# Evaluating the Model on the Training Data and Validation Data
training_predictions = catboost_clf.predict(train_x)
validation_predictions = catboost_clf.predict(valid_x)
train_metrics = get_metrics(train_y,training_predictions)
valid_metrics = get_metrics(valid_y,validation_predictions)
train_metrics_df = {'Name':'Gradient Boosting','F1':train_metrics[0],'Precision':train_metrics[1],'Recall':train_metrics[2],'Accuracy':train_metrics[3]}
valid_metrics_df = {'Name':'Gradient Boosting','F1':valid_metrics[0],'Precision':valid_metrics[1],'Recall':valid_metrics[2],'Accuracy':valid_metrics[3]}

# %%
# Training metrics
train_metrics_df
# Out:
# {'Name': 'Gradient Boosting',
#  'F1': 0.7834370139968897,
#  'Precision': 0.7973882073605065,
#  'Recall': 0.7699656094764998,
#  'Accuracy': 0.8170771756978653}

# %%
# Validation metrics
valid_metrics_df
# Out:
# {'Name': 'Gradient Boosting',
#  'F1': 0.7535680304471932,
#  'Precision': 0.75,
#  'Recall': 0.7571701720841301,
#  'Accuracy': 0.7873563218390804}

# %%
# Saving the model
with open('gradient-boosting.sav','wb') as file:
    pickle.dump(catboost_clf,file)

# %% [markdown]
# ## Deep Learning Models
#
# Now, I need to prepare the data into a sequence format for deep learning models

# %%
# Importing the data
raw_train = pd.read_csv('train.csv')

# Splitting the data into training, validation, and testing
training, testing = train_test_split(raw_train,test_size=0.2,random_state=42,shuffle=True,stratify=raw_train['target'])
validation, testing = train_test_split(testing,test_size=0.2,random_state=42,shuffle=True,stratify=testing['target'])
training.reset_index(drop=True,inplace=True)
validation.reset_index(drop=True,inplace=True)
testing.reset_index(drop=True,inplace=True)

# Splitting data into X & Y
train_x = training.drop(['target'],axis=1)
train_y = training['target'].values
valid_x = validation.drop(['target'],axis=1)
valid_y = validation['target'].values

# Getting the preprocessed text
preprocessor = Preprocessing()
preprocessed_train_x = preprocessor.preprocess_data(train_x)
preprocessed_valid_x = preprocessor.preprocess_data(valid_x)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Transforming data to (number of examples, 57, 1000)
training_X = []
valid_X = []

# Opening the vocabulary and marking 1 to indicate the word
with open('word2index.json') as file:
    vocabulary = json.load(file)

    # Iterating through the training
    for sentence_index in range(0,len(preprocessed_train_x)):
        sentence_convert = [1001] * 57
        for word_index in range(0,len(preprocessed_train_x[sentence_index])):
            # If the word is in the vocab, get the index
            word = preprocessed_train_x[sentence_index][word_index]
            if word in vocabulary.keys():
                sentence_convert[word_index] = vocabulary[word]
            else:
                sentence_convert[word_index] = 1000

        training_X.append(sentence_convert)

    # Iterating through the validation
    for sentence_index in range(0,len(preprocessed_valid_x)):
        sentence_convert = [1001] * 57
        for word_index in range(0,len(preprocessed_valid_x[sentence_index])):
            # If the word is in the vocab, get the index
            word = preprocessed_valid_x[sentence_index][word_index]
            if word in vocabulary.keys():
                sentence_convert[word_index] = vocabulary[word]
            else:
                sentence_convert[word_index] = 1000

        valid_X.append(sentence_convert)

training_X = np.array(training_X)
valid_X = np.array(valid_X)

# %% [markdown]
# ### GRU

# %%
# Defining a function to build the GRU model
def build_gru(embedding_dim=50,hidden_units=50,dropout_rate=0.2,lr=0.001,regularization_constant=0.01):
    gru_clf = Sequential()
    gru_clf.add(Embedding(input_dim=1002,output_dim=embedding_dim,input_length=training_X.shape[1]))
    gru_clf.add(BatchNormalization())
    gru_clf.add(Dropout(rate=dropout_rate))
    gru_clf.add(GRU(units=hidden_units,activation='tanh',recurrent_activation='sigmoid',bias_initializer='ones',return_sequences=False,
                    kernel_regularizer=keras.regularizers.L2(l2=regularization_constant)))
    gru_clf.add(BatchNormalization())
    gru_clf.add(Dropout(rate=dropout_rate))
    gru_clf.add(Dense(1,activation='sigmoid',bias_initializer='ones'))

    # Compiling the model
    loss_function = 'binary_crossentropy'
    optimizer = keras.optimizers.Adam(learning_rate=lr)
    gru_clf.compile(optimizer,loss_function,metrics=[keras.metrics.F1Score(threshold=0.5)])

    # returning the model
    return gru_clf

# %%
# Tuning the GRU
early_stopping = keras.callbacks.EarlyStopping(monitor='val_f1_score',patience=10,restore_best_weights=True,mode='max')
gru_model = build_gru(embedding_dim=15,hidden_units=12,dropout_rate=0.3,lr=0.001,regularization_constant=0.75)
history = gru_model.fit(training_X,tf.cast(train_y,float),epochs=50,batch_size=32,validation_data=(valid_X,tf.cast(valid_y,float)),callbacks=early_stopping)
# Out:
# Epoch 1/50
# 191/191 [==============================] - 15s 53ms/step - loss: 7.8091 - f1_score: 0.6391 - val_loss: 3.0299 - val_f1_score: 0.0000e+00
# Epoch 2/50
# 191/191 [==============================] - 3s 16ms/step - loss: 1.4541 - f1_score: 0.7326 - val_loss: 1.0016 - val_f1_score: 0.6008
# Epoch 3/50
# 191/191 [==============================] - 2s 12ms/step - loss: 0.5489 - f1_score: 0.7442 - val_loss: 0.5759 - val_f1_score: 0.5440
# Epoch 4/50
# 191/191 [==============================] - 2s 13ms/step - loss: 0.4528 - f1_score: 0.7556 - val_loss: 0.9655 - val_f1_score: 0.6122
# Epoch 5/50
# 191/191 [==============================] - 3s 14ms/step - loss: 0.4382 - f1_score: 0.7638 - val_loss: 0.5902 - val_f1_score: 0.7048
# Epoch 6/50
# 191/191 [==============================] - 2s 10ms/step - loss: 0.4293 - f1_score: 0.7658 - val_loss: 0.4859 - val_f1_score: 0.7591
# Epoch 7/50
# 191/191 [==============================] - 2s 11ms/step - loss: 0.4179 - f1_score: 0.7810 - val_loss: 0.9774 - val_f1_score: 0.4127
# Epoch 8/50
# 191/191 [==============================] - 2s 10ms/step - loss: 0.4094 - f1_score: 0.7911 - val_loss: 0.6691 - val_f1_score: 0.6277
# Epoch 9/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.3992 - f1_score: 0.7925 - val_loss: 1.7273 - val_f1_score: 0.3449
# Epoch 10/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.3945 - f1_score: 0.7965 - val_loss: 0.4874 - val_f1_score: 0.7406
# Epoch 11/50
# 191/191 [==============================] - 3s 14ms/step - loss: 0.3975 - f1_score: 0.7863 - val_loss: 6.3274 - val_f1_score: 0.6008
# Epoch 12/50
# 191/191 [==============================] - 2s 12ms/step - loss: 0.3809 - f1_score: 0.8083 - val_loss: 1.0999 - val_f1_score: 0.4091
# Epoch 13/50
# 191/191 [==============================] - 2s 10ms/step - loss: 0.3755 - f1_score: 0.8060 - val_loss: 1.0360 - val_f1_score: 0.6485
# Epoch 14/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.3754 - f1_score: 0.8097 - val_loss: 0.9293 - val_f1_score: 0.5477
# Epoch 15/50
# 191/191 [==============================] - 2s 8ms/step - loss: 0.3655 - f1_score: 0.8128 - val_loss: 6.5102 - val_f1_score: 0.6008
# Epoch 16/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.3649 - f1_score: 0.8122 - val_loss: 7.0640 - val_f1_score: 0.6008

# %%
# Evaluating the Model on the Training Data and Validation Data
training_predictions = gru_model.predict(training_X)
validation_predictions = gru_model.predict(valid_X)
train_metrics = get_metrics(train_y,np.rint(training_predictions))
valid_metrics = get_metrics(valid_y,np.rint(validation_predictions))
train_metrics_df = {'Name':'GRU','F1':train_metrics[0],'Precision':train_metrics[1],'Recall':train_metrics[2],'Accuracy':train_metrics[3]}
valid_metrics_df = {'Name':'GRU','F1':valid_metrics[0],'Precision':valid_metrics[1],'Recall':valid_metrics[2],'Accuracy':valid_metrics[3]}
# Out:
# 191/191 [==============================] - 1s 3ms/step
# 39/39 [==============================] - 0s 3ms/step

# %%
# Viewing the training metrics
train_metrics_df
# Out:
# {'Name': 'GRU',
#  'F1': 0.8098484848484848,
#  'Precision': 0.8028539241457003,
#  'Recall': 0.8169659915934276,
#  'Accuracy': 0.8351395730706076}

# %%
# Viewing the validation metrics
valid_metrics_df

# %%
# Saving the model
gru_model.save('gru.keras')

# %% [markdown]
# ### LSTM

# %%
# Defining a function to build the LSTM model
def build_lstm(embedding_dim=50,hidden_units=50,dropout_rate=0.2,lr=0.0001):
    lstm_clf = Sequential()
    lstm_clf.add(Embedding(input_dim=1002,output_dim=embedding_dim,input_length=training_X.shape[1]))
    lstm_clf.add(BatchNormalization())
    lstm_clf.add(Dropout(rate=dropout_rate))
    lstm_clf.add(LSTM(units=hidden_units,activation='tanh',recurrent_activation='sigmoid',return_sequences=False))
    lstm_clf.add(BatchNormalization())
    lstm_clf.add(Dropout(rate=dropout_rate))
    lstm_clf.add(Dense(1,activation='sigmoid',bias_initializer='ones'))
    loss_function = 'binary_crossentropy'
    optimizer = keras.optimizers.Adam(learning_rate=lr)
    lstm_clf.compile(optimizer,loss_function,metrics=[keras.metrics.F1Score(threshold=0.5)])

    # returning the model
    return lstm_clf

# %%
# Tuning the LSTM
early_stopping = keras.callbacks.EarlyStopping(monitor='val_f1_score',patience=10,restore_best_weights=True,mode='max')
lstm_model = build_lstm(embedding_dim=15,hidden_units=5,dropout_rate=0.2,lr=0.001)
history = lstm_model.fit(training_X,tf.cast(train_y,float),epochs=50,batch_size=32,validation_data=(valid_X,tf.cast(valid_y,float)),callbacks=early_stopping)
# Out:
# Epoch 1/50
# 191/191 [==============================] - 14s 47ms/step - loss: 0.8145 - f1_score: 0.5945 - val_loss: 0.7706 - val_f1_score: 0.6008
# Epoch 2/50
# 191/191 [==============================] - 4s 22ms/step - loss: 0.6982 - f1_score: 0.5226 - val_loss: 0.6605 - val_f1_score: 0.0226
# Epoch 3/50
# 191/191 [==============================] - 2s 11ms/step - loss: 0.5449 - f1_score: 0.6826 - val_loss: 2.2655 - val_f1_score: 0.6008
# Epoch 4/50
# 191/191 [==============================] - 2s 13ms/step - loss: 0.4835 - f1_score: 0.7342 - val_loss: 0.4949 - val_f1_score: 0.7617
# Epoch 5/50
# 191/191 [==============================] - 2s 12ms/step - loss: 0.4436 - f1_score: 0.7668 - val_loss: 2.4499 - val_f1_score: 0.6008
# Epoch 6/50
# 191/191 [==============================] - 2s 12ms/step - loss: 0.4231 - f1_score: 0.7832 - val_loss: 0.4921 - val_f1_score: 0.7218
# Epoch 7/50
# 191/191 [==============================] - 2s 11ms/step - loss: 0.4122 - f1_score: 0.7884 - val_loss: 0.6279 - val_f1_score: 0.5302
# Epoch 8/50
# 191/191 [==============================] - 3s 14ms/step - loss: 0.3820 - f1_score: 0.8024 - val_loss: 0.8904 - val_f1_score: 0.7016
# Epoch 9/50
# 191/191 [==============================] - 2s 10ms/step - loss: 0.3785 - f1_score: 0.8081 - val_loss: 0.6216 - val_f1_score: 0.7162
# Epoch 10/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.3639 - f1_score: 0.8155 - val_loss: 1.5215 - val_f1_score: 0.6008
# Epoch 11/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.3483 - f1_score: 0.8254 - val_loss: 0.7282 - val_f1_score: 0.6289
# Epoch 12/50
# 191/191 [==============================] - 2s 10ms/step - loss: 0.3369 - f1_score: 0.8330 - val_loss: 0.5241 - val_f1_score: 0.7147
# Epoch 13/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.3195 - f1_score: 0.8473 - val_loss: 1.3607 - val_f1_score: 0.3381
# Epoch 14/50
# 191/191 [==============================] - 2s 12ms/step - loss: 0.3135 - f1_score: 0.8420 - val_loss: 0.6891 - val_f1_score: 0.7407

# %%
# Evaluating the Model on the Training Data and Validation Data
training_predictions = lstm_model.predict(training_X)
validation_predictions = lstm_model.predict(valid_X)
train_metrics = get_metrics(train_y,np.rint(training_predictions))
valid_metrics = get_metrics(valid_y,np.rint(validation_predictions))
train_metrics_df = {'Name':'LSTM','F1':train_metrics[0],'Precision':train_metrics[1],'Recall':train_metrics[2],'Accuracy':train_metrics[3]}
valid_metrics_df = {'Name':'LSTM','F1':valid_metrics[0],'Precision':valid_metrics[1],'Recall':valid_metrics[2],'Accuracy':valid_metrics[3]}
# Out:
# 191/191 [==============================] - 1s 3ms/step
# 39/39 [==============================] - 0s 3ms/step

# %%
train_metrics_df
# Out:
# {'Name': 'LSTM',
#  'F1': 0.8064516129032259,
#  'Precision': 0.7918968692449355,
#  'Recall': 0.8215513947267864,
#  'Accuracy': 0.8305418719211822}

# %%
valid_metrics_df
# Out:
# {'Name': 'LSTM',
#  'F1': 0.7617295308187673,
#  'Precision': 0.7340425531914894,
#  'Recall': 0.7915869980879541,
#  'Accuracy': 0.7873563218390804}

# %%
# Saving the model
lstm_model.save('lstm.keras')
